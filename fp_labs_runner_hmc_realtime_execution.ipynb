# %% [markdown]
# ***
# # **FloodProofs Labs - HMC Training - Model Runner - Realtime Execution**
#
# <img style="float: left; padding-right: 80px; padding-left: 5px;" src="img/logo_hmc.png" width="200px" align=”left” >
#
# In the laboratory of **Continuum Model Runner - Realtime Execution** we will perform the following points:
#    * Configure the libraries and the dependecies of the laboratory;
#    * Read the configuration file of the laboratory;
#    * Initialize the instance of the Continuum model --> Configure the algorithm and the ancillary datasets;
#    * Build the instance of the Continumm model --> Configure the static and dynamic datasets;
#    * Run the instance of the Continuum model --> Execute the Continuum model
#    * Finalize the instance of the Continuum model --> Organize and dump the outcome datasets.

# %% [markdown]
# ### **Import libraries and dependencies**

# %%
# %matplotlib inline
# %matplotlib widget

# %%
# Add hmc library to the paths environment
import sys
import os

# Info
print(' ==> Add HMC library in the environment ... ') 

folder_home_env = os.path.expanduser('~')
folder_library_hmc = "/fp_labs_hmc/library/jupyter_hmc/"

folder_library_hmc = folder_home_env + folder_library_hmc
sys.path.append(folder_library_hmc)

# Info
print(' ===> Added in: ' + folder_library_hmc)
print(' ==> Add HMC library in the environment ... DONE')
# Out:
#  ==> Add HMC library in the environment ...
#  ===> Added in: /home/fabio/fp_labs_hmc/library/jupyter_hmc/
#  ==> Add HMC library in the environment ... DONE

# %%
# Libraries
print(' ==> Load generic and package libraries ... ')

import pickle
import argparse
import logging
import time
import pandas as pd

# Import method to adapt settings file
from library.jupyter_generic.lib_jupyter_data_io_generic import define_file_path, define_file_template, \
    fill_file_template, create_dframe_ts, get_path_root, get_path_folders, get_folders_time

from library.jupyter_generic.lib_jupyter_utils_io import update_json_file
from library.jupyter_generic.lib_jupyter_data_io_json import read_file_settings

# Import coupler and driver classes
from hmc.driver.configuration.drv_configuration_hmc_logging import ModelLogging
from hmc.coupler.cpl_hmc_manager import ModelInitializer, ModelCleaner
from hmc.coupler.cpl_hmc_builder import ModelBuilder
from hmc.coupler.cpl_hmc_runner import ModelRunner
from hmc.coupler.cpl_hmc_finalizer import ModelFinalizer

import ipywidgets as widgets
from ipywidgets import interact, interact_manual

def write_pickle(file_name, file_data):
    if os.path.exists(file_name):
        os.remove(file_name)
    with open(file_name,'wb') as file_handle:
        pickle.dump(file_data, file_handle) 

def read_pickle(file_name):
    if not os.path.exists(file_name):
        raise IOError('File ' + file_name + ' not found!')
    file_handle = open(file_name,'rb')  
    file_data = pickle.load(file_handle)  
    return file_data

# File name for sharing variable(s)
file_name_settings = "fp_labs_runner_hmc_realtime_execution.json"
file_name_shared_vars = "shared_variables.workspace"

# Info
print(' ==> Load generic and package libraries ... DONE')
# Out:
#  ==> Load generic and package libraries ...
#  ==> Load generic and package libraries ... DONE

# %% [markdown]
# ### **Configure the Continuum laboratory**
# - Set the notebook arguments:

# %%
# Define filename by template definition(s)
print(' ==> Define settings args ... ')

# Read data from settings algorithm file
settings_info = read_file_settings(file_name_settings)

info_time_run = settings_info['info']['time_run']
info_domain = settings_info['info']['domain_name']
info_run_name = settings_info['info']['run_name']

script_settings_default = define_file_path(settings_info['configuration_info']['default'])
script_settings_defined = define_file_path(settings_info['configuration_info']['defined'])

script_datasets_defined = define_file_path(settings_info['datasets_info'])

# Info
print(' ===> TimeRun: ' + str(info_time_run))
print(' ===> DomainName: ' + info_domain)
print(' ===> RunName: ' + info_run_name)
print(' ==> Define settings args ... DONE')
# Out:
#  ==> Define settings args ...
#  ===> TimeRun: None
#  ===> DomainName: marche
#  ===> RunName: jupyter_ws
#  ==> Define settings args ... DONE

# %%
# Get static and dynamic filename(s)
file_path_section_shp = script_datasets_defined['data_static']
file_path_run_ts_img = script_datasets_defined['run_realtime_ts_images']
file_path_run_ts_hydro = script_datasets_defined['run_realtime_ts_hydrograph']

# Get data dynamic root folder
folder_name_dynamic_root = get_path_folders(script_datasets_defined['data_dynamic'])

# %%
# Define list of available folders and time(s)
time_run_available = get_folders_time(folder_name_dynamic_root)

# %%
# Display available time run
time_run_selection = widgets.Select(options=time_run_available, description='Time Run', disabled=False)
display(time_run_selection)
# Out:
# Select(description='Time Run', options=('2021-01-22 06:00', '2021-01-28 12:00'), value='2021-01-22 06:00')

# %%
# Parser the selection from the scroll menu and define the time as a timestamp object
info_time_run = pd.Timestamp(time_run_selection.value)

# Info time run
print(' ==> Time Run: ' + str(info_time_run) )
# Out:
#  ==> Time Run: 2021-01-22 06:00:00

# %%
# Define filename by template definition(s)
print(' ==> Define folder and file name ... ')

file_template_filled = define_file_template(
    info_time_run, run_name=info_run_name, domain_name=info_domain, template_default=settings_info['template'])

script_settings_defined['settings_algorithm'] = fill_file_template(
    script_settings_defined['settings_algorithm'],
    template_filled=file_template_filled, template_default=settings_info['template'])

script_settings_defined['settings_datasets'] = fill_file_template(
    script_settings_defined['settings_datasets'],
    template_filled=file_template_filled, template_default=settings_info['template'])

file_path_run_ts_img = fill_file_template(
    file_path_run_ts_img, template_filled=file_template_filled, template_default=settings_info['template'])
file_path_run_ts_hydro = fill_file_template(
    file_path_run_ts_hydro, template_filled=file_template_filled, template_default=settings_info['template'])

# Info
print(' ===> Filename Section: ' + file_path_section_shp)
print(' ===> Filename Hydrograph: ' + file_path_run_ts_hydro)
print(' ===> Filename Images: ' + file_path_run_ts_img)
print(' ==> Define folder and file name ... DONE')
# Out:
#  ==> Define folder and file name ...
#  ===> Filename Section: /home/fabio/fp_labs_datasets/data_static/shapefile/fp_sections_marche.shp
#  ===> Filename Hydrograph: /home/fabio/fp_run_hmc/jupyter_ws/outcome/timeseries/hmc.hydrograph.txt
#  ===> Filename Images: /home/fabio/fp_run_hmc/jupyter_ws/outcome/images/hmc_ts_group{group_name}_{time_name}.png
#  ==> Define folder and file name ... DONE

# %% [markdown]
# - Update the configuration file(s) according with the environment variable(s)

# %%
# Info
print(' ==> Update configuration file(s) ... ')

# Set environment variables to json settings file(s)
update_json_file(script_settings_default['settings_algorithm'], script_settings_defined['settings_algorithm'],
                 update_dict={'$ENV_HOME': folder_home_env, 
                              '$ENV_TIME': info_time_run.strftime("%Y%m%d_%H"), '$ENV_RUN_NAME': info_run_name})
update_json_file(script_settings_default['settings_datasets'], script_settings_defined['settings_datasets'],
                 update_dict={'$ENV_HOME': folder_home_env, 
                              '$ENV_TIME': info_time_run.strftime("%Y%m%d_%H"), '$ENV_RUN_NAME': info_run_name})

script_settings_algorithm_defined = script_settings_defined['settings_algorithm']
script_settings_datasets_defined = script_settings_defined['settings_datasets']

# Info
print(' ===> Settings algorithm file: ' + script_settings_algorithm_defined)
print(' ===> Settings datasets file: ' + script_settings_datasets_defined)
print(' ==> Update configuration file(s) ... DONE')
# Out:
#  ==> Update configuration file(s) ...
#  ===> Settings algorithm file: /home/fabio/fp_labs_hmc/fp_labs_runner_hmc_algorithm_202101220600.json
#  ===> Settings datasets file: /home/fabio/fp_labs_hmc/fp_labs_runner_hmc_datasets_202101220600.json
#  ==> Update configuration file(s) ... DONE

# %% [markdown]
# ### **Initialize the instance of the Continuum model**
# - Set the logging file:

# %%
# Info
print(' ==> Set logging file ... ')

# Set logging file
driver_hmc_logging = ModelLogging(script_settings_algorithm_defined)
log_stream = driver_hmc_logging.configure_logging()

# Set the verbose debug level
log_stream.setLevel(logging.WARNING)

# Info
print(' ==> Set logging file ... DONE')
# Out:
#  ==> Set logging file ...
#  ==> Set logging file ... DONE

# %% [markdown]
# - Configure the model initializer class

# %%
# Info
print(' ==> Configure the model initializer class ... ')

# Set the verbose debug level
log_stream.setLevel(logging.ERROR)

# Configure model initializer class
driver_hmc_initializer = ModelInitializer(file_algorithm=script_settings_algorithm_defined,
                                          file_datasets=script_settings_datasets_defined, time=info_time_run)

# Info
print(' ==> Configure the model initializer class ... DONE')
# Out:
#  ==> Configure the model initializer class ...
#  ==> Configure the model initializer class ... DONE

# %% [markdown]
# - Configure the algorithm and the ancillary datasets

# %%
# Configure algorithm
time_series_collections, time_info_collections, \
    run_info_collections, run_cline_collections = driver_hmc_initializer.configure_algorithm()

# %%
# Configure ancillary datasets
ancillary_datasets_collections = driver_hmc_initializer.configure_ancillary_datasets(time_info_collections)

# %% [markdown]
# ### **Build the instance of the Continuum model**
# - Configure the model builder class

# %%
# Info
print(' ==> Configure the model builder class ... ')

# Set the verbose debug level
log_stream.setLevel(logging.WARNING)

# Configure model builder class
driver_hmc_builder = ModelBuilder(
    obj_geo_reference=driver_hmc_initializer.dset_ref_geo,
    obj_args=driver_hmc_initializer.obj_args,
    obj_run=driver_hmc_initializer.obj_run,
    obj_ancillary=driver_hmc_initializer.obj_ancillary)

# Info
print(' ==> Configure the model builder class ... DONE')
# Out:
#  ==> Configure the model builder class ...
#  ==> Configure the model builder class ... DONE

# %% [markdown]
# - Dump variable to initialize the notebook for realtime plot(s)

# %%
# Info
print(' ==> Dump shared variables ... ')

# Dump variable to pickle ==> TO SET THE SECOND NOTEBOOK
variables_shared={'time_series_collections': time_series_collections, 
                  'time_run': info_time_run, 'run_name': info_run_name,
                  'file_name_section': file_path_section_shp, 'file_name_hydrograph': file_path_run_ts_hydro,
                  'file_name_images': file_path_run_ts_img,
                  'driver_hmc_builder': driver_hmc_builder}
write_pickle(file_name_shared_vars, variables_shared)

# Info
print(' ==> Dump shared variables ... DONE')
# Out:
#  ==> Dump shared variables ...
#  ==> Dump shared variables ... DONE

# %% [markdown]
# - Organize the static and the dynamic datasets

# %%
# Info
print(' ==> Organize the model static datasets ... ')

# Set the verbose debug level
log_stream.setLevel(logging.ERROR)

# Configure static datasets
static_datasets_collections = driver_hmc_builder.configure_static_datasets(ancillary_datasets_collections)

# Info
print(' ==> Organize the model static datasets ... DONE')
# Out:
#  ==> Organize the model static datasets ...
#  ==> Organize the model static datasets ... DONE

# %%
# Info
print(' ==> Organize the model dynamic datasets ... ')

# Set the verbose debug level
log_stream.setLevel(logging.INFO)

# Configure dynamic datasets
forcing_datasets_collections = driver_hmc_builder.configure_dynamic_datasets(
    time_series_collections, time_info_collections, static_datasets_collections, ancillary_datasets_collections)

# Info
print(' ==> Organize the model dynamic datasets ... DONE')
# Out:
# 2021-01-29 17:03:23,293 hmc_logger   INFO      #### Configure dynamic source datasets ...                                      cpl_hmc_builder.py:[112    - configure_dynamic_datasets()]
# 2021-01-29 17:03:23,298 hmc_logger   INFO      ----> Organize dynamic datasets ...                                             drv_dataset_hmc_base_source.py:[459    - organize_data_dynamic()]
# 2021-01-29 17:03:23,299 hmc_logger   INFO      -----> Run deterministic ...                                                    drv_dataset_hmc_base_source.py:[483    - organize_data_dynamic()]
# 2021-01-29 17:03:23,301 hmc_logger   INFO      ------> Collect Gridded source filename(s) ...                                  drv_dataset_hmc_io_dynamic_forcing.py:[936    - collect_filename    ()]
# 2021-01-29 17:03:23,303 hmc_logger   INFO      -------> Type ARCHIVE ...                                                       drv_dataset_hmc_io_dynamic_forcing.py:[945    - collect_filename    ()]
# 2021-01-29 17:03:23,305 hmc_logger   INFO      --------> Variable ALL ...                                                      drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,308 hmc_logger   INFO      --------> Variable ALL ... DONE                                                 drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,310 hmc_logger   INFO      -------> Type ARCHIVE ... DONE                                                  drv_dataset_hmc_io_dynamic_forcing.py:[1109   - collect_filename    ()]
# 2021-01-29 17:03:23,320 hmc_logger   INFO      ------> Collect Gridded source filename(s) ... DONE                             drv_dataset_hmc_io_dynamic_forcing.py:[1145   - collect_filename    ()]
# 2021-01-29 17:03:23,321 hmc_logger   INFO      ------> Collect Point source filename(s) ...                                    drv_dataset_hmc_io_dynamic_forcing.py:[936    - collect_filename    ()]
# 2021-01-29 17:03:23,322 hmc_logger   INFO      -------> Type ARCHIVE ...                                                       drv_dataset_hmc_io_dynamic_forcing.py:[945    - collect_filename    ()]
# 2021-01-29 17:03:23,325 hmc_logger   INFO      --------> Variable ALL ...                                                      drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,327 hmc_logger   INFO      --------> Variable ALL ... DONE                                                 drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,328 hmc_logger   INFO      -------> Type ARCHIVE ... DONE                                                  drv_dataset_hmc_io_dynamic_forcing.py:[1109   - collect_filename    ()]
# 2021-01-29 17:03:23,342 hmc_logger   INFO      ------> Collect Point source filename(s) ... DONE                               drv_dataset_hmc_io_dynamic_forcing.py:[1145   - collect_filename    ()]
# 2021-01-29 17:03:23,346 hmc_logger   INFO      ------> Collect Gridded model filename(s) ...                                   drv_dataset_hmc_io_dynamic_forcing.py:[1152   - collect_filename    ()]
# 2021-01-29 17:03:23,356 hmc_logger   INFO      ------> Collect Gridded model filename(s) ... DONE                              drv_dataset_hmc_io_dynamic_forcing.py:[1276   - collect_filename    ()]
# 2021-01-29 17:03:23,358 hmc_logger   INFO      ------> Collect Point model filename(s) ...                                     drv_dataset_hmc_io_dynamic_forcing.py:[1152   - collect_filename    ()]
# 2021-01-29 17:03:23,368 hmc_logger   INFO      ------> Collect Point model filename(s) ... DONE                                drv_dataset_hmc_io_dynamic_forcing.py:[1276   - collect_filename    ()]
# 2021-01-29 17:03:23,370 hmc_logger   INFO      -----> Run deterministic ... DONE                                               drv_dataset_hmc_base_source.py:[492    - organize_data_dynamic()]
# 2021-01-29 17:03:23,372 hmc_logger   INFO      ----> Organize dynamic datasets ... DONE                                        drv_dataset_hmc_base_source.py:[495    - organize_data_dynamic()]
# 2021-01-29 17:03:23,375 hmc_logger   INFO      ----> Organize dynamic datasets ...                                             drv_dataset_hmc_base_source.py:[459    - organize_data_dynamic()]
# 2021-01-29 17:03:23,376 hmc_logger   INFO      -----> Run deterministic ...                                                    drv_dataset_hmc_base_source.py:[483    - organize_data_dynamic()]
# 2021-01-29 17:03:23,377 hmc_logger   INFO      ------> Collect Gridded source filename(s) ...                                  drv_dataset_hmc_io_dynamic_forcing.py:[936    - collect_filename    ()]
# 2021-01-29 17:03:23,378 hmc_logger   INFO      -------> Type OBS ...                                                           drv_dataset_hmc_io_dynamic_forcing.py:[945    - collect_filename    ()]
# 2021-01-29 17:03:23,382 hmc_logger   INFO      --------> Variable Rain ...                                                     drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,394 hmc_logger   INFO      --------> Variable Rain ... DONE                                                drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,396 hmc_logger   INFO      --------> Variable AirTemperature ...                                           drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,407 hmc_logger   INFO      --------> Variable AirTemperature ... DONE                                      drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,408 hmc_logger   INFO      --------> Variable Wind ...                                                     drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,419 hmc_logger   INFO      --------> Variable Wind ... DONE                                                drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,422 hmc_logger   INFO      --------> Variable RelHumidity ...                                              drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,430 hmc_logger   INFO      --------> Variable RelHumidity ... DONE                                         drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,432 hmc_logger   INFO      --------> Variable IncRadiation ...                                             drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,444 hmc_logger   INFO      --------> Variable IncRadiation ... DONE                                        drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,446 hmc_logger   INFO      --------> Variable AirPressure ...                                              drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,457 hmc_logger   INFO      --------> Variable AirPressure ... DONE                                         drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,459 hmc_logger   INFO      --------> Variable SnowHeight ...                                               drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,469 hmc_logger   INFO      --------> Variable SnowHeight ... DONE                                          drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,470 hmc_logger   INFO      --------> Variable SnowKernel ...                                               drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,482 hmc_logger   INFO      --------> Variable SnowKernel ... DONE                                          drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,484 hmc_logger   INFO      --------> Variable SnowCoverArea ...                                            drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
#  ==> Organize the model dynamic datasets ...
# 2021-01-29 17:03:23,495 hmc_logger   INFO      --------> Variable SnowCoverArea ... DONE                                       drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,497 hmc_logger   INFO      --------> Variable SnowQualityArea ...                                          drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,509 hmc_logger   INFO      --------> Variable SnowQualityArea ... DONE                                     drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,511 hmc_logger   INFO      -------> Type OBS ... DONE                                                      drv_dataset_hmc_io_dynamic_forcing.py:[1109   - collect_filename    ()]
# 2021-01-29 17:03:23,513 hmc_logger   INFO      -------> Type FOR ...                                                           drv_dataset_hmc_io_dynamic_forcing.py:[945    - collect_filename    ()]
# 2021-01-29 17:03:23,516 hmc_logger   INFO      --------> Variable Rain ...                                                     drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,518 hmc_logger   INFO      --------> Variable Rain ... DONE                                                drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,518 hmc_logger   INFO      --------> Variable AirTemperature ...                                           drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,520 hmc_logger   INFO      --------> Variable AirTemperature ... DONE                                      drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,521 hmc_logger   INFO      --------> Variable Wind ...                                                     drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,523 hmc_logger   INFO      --------> Variable Wind ... DONE                                                drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,524 hmc_logger   INFO      --------> Variable RelHumidity ...                                              drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,526 hmc_logger   INFO      --------> Variable RelHumidity ... DONE                                         drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,527 hmc_logger   INFO      --------> Variable IncRadiation ...                                             drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,528 hmc_logger   INFO      --------> Variable IncRadiation ... DONE                                        drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,529 hmc_logger   INFO      --------> Variable AirPressure ...                                              drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,530 hmc_logger   INFO      --------> Variable AirPressure ... DONE                                         drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,532 hmc_logger   INFO      -------> Type FOR ... DONE                                                      drv_dataset_hmc_io_dynamic_forcing.py:[1109   - collect_filename    ()]
# 2021-01-29 17:03:23,574 hmc_logger   INFO      ------> Collect Gridded source filename(s) ... DONE                             drv_dataset_hmc_io_dynamic_forcing.py:[1145   - collect_filename    ()]
# 2021-01-29 17:03:23,576 hmc_logger   INFO      ------> Collect Point source filename(s) ...                                    drv_dataset_hmc_io_dynamic_forcing.py:[936    - collect_filename    ()]
# 2021-01-29 17:03:23,577 hmc_logger   INFO      -------> Type OBS ...                                                           drv_dataset_hmc_io_dynamic_forcing.py:[945    - collect_filename    ()]
# 2021-01-29 17:03:23,580 hmc_logger   INFO      --------> Variable Discharge ...                                                drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,592 hmc_logger   INFO      --------> Variable Discharge ... DONE                                           drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,594 hmc_logger   INFO      --------> Variable DamV ...                                                     drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,596 hmc_logger   INFO      --------> Variable DamV ... SKIPPED. Datasets folder or filename are null.      drv_dataset_hmc_io_dynamic_forcing.py:[1064   - collect_filename    ()]
# 2021-01-29 17:03:23,598 hmc_logger   WARNING   ===> Datasets for variable DamV is empty                                        drv_dataset_hmc_io_dynamic_forcing.py:[1086   - collect_filename    ()]
# 2021-01-29 17:03:23,599 hmc_logger   INFO      --------> Variable DamV ... DONE                                                drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,600 hmc_logger   INFO      --------> Variable DamL ...                                                     drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,601 hmc_logger   INFO      --------> Variable DamL ... SKIPPED. Datasets folder or filename are null.      drv_dataset_hmc_io_dynamic_forcing.py:[1064   - collect_filename    ()]
# 2021-01-29 17:03:23,607 hmc_logger   WARNING   ===> Datasets for variable DamL is empty                                        drv_dataset_hmc_io_dynamic_forcing.py:[1086   - collect_filename    ()]
# 2021-01-29 17:03:23,609 hmc_logger   INFO      --------> Variable DamL ... DONE                                                drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,610 hmc_logger   INFO      -------> Type OBS ... DONE                                                      drv_dataset_hmc_io_dynamic_forcing.py:[1109   - collect_filename    ()]
# 2021-01-29 17:03:23,611 hmc_logger   INFO      -------> Type FOR ...                                                           drv_dataset_hmc_io_dynamic_forcing.py:[945    - collect_filename    ()]
# 2021-01-29 17:03:23,615 hmc_logger   INFO      -------> Type FOR ... SKIPPED. Datasets is empty                                drv_dataset_hmc_io_dynamic_forcing.py:[1111   - collect_filename    ()]
# 2021-01-29 17:03:23,632 hmc_logger   INFO      ------> Collect Point source filename(s) ... DONE                               drv_dataset_hmc_io_dynamic_forcing.py:[1145   - collect_filename    ()]
# 2021-01-29 17:03:23,634 hmc_logger   INFO      ------> Collect TimeSeries source filename(s) ...                               drv_dataset_hmc_io_dynamic_forcing.py:[936    - collect_filename    ()]
# 2021-01-29 17:03:23,635 hmc_logger   INFO      -------> Type OBS ...                                                           drv_dataset_hmc_io_dynamic_forcing.py:[945    - collect_filename    ()]
# 2021-01-29 17:03:23,637 hmc_logger   INFO      --------> Variable DamQ ...                                                     drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,639 hmc_logger   INFO      --------> Variable DamQ ... SKIPPED. Datasets folder or filename are null.      drv_dataset_hmc_io_dynamic_forcing.py:[1064   - collect_filename    ()]
# 2021-01-29 17:03:23,640 hmc_logger   WARNING   ===> Datasets for variable DamQ is empty                                        drv_dataset_hmc_io_dynamic_forcing.py:[1086   - collect_filename    ()]
# 2021-01-29 17:03:23,642 hmc_logger   INFO      --------> Variable DamQ ... DONE                                                drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,643 hmc_logger   INFO      --------> Variable IntakeQ ...                                                  drv_dataset_hmc_io_dynamic_forcing.py:[980    - collect_filename    ()]
# 2021-01-29 17:03:23,645 hmc_logger   INFO      --------> Variable IntakeQ ... SKIPPED. Datasets folder or filename are null.   drv_dataset_hmc_io_dynamic_forcing.py:[1064   - collect_filename    ()]
# 2021-01-29 17:03:23,646 hmc_logger   WARNING   ===> Datasets for variable IntakeQ is empty                                     drv_dataset_hmc_io_dynamic_forcing.py:[1086   - collect_filename    ()]
# 2021-01-29 17:03:23,648 hmc_logger   INFO      --------> Variable IntakeQ ... DONE                                             drv_dataset_hmc_io_dynamic_forcing.py:[1107   - collect_filename    ()]
# 2021-01-29 17:03:23,649 hmc_logger   INFO      -------> Type OBS ... DONE                                                      drv_dataset_hmc_io_dynamic_forcing.py:[1109   - collect_filename    ()]
# 2021-01-29 17:03:23,650 hmc_logger   INFO      -------> Type FOR ...                                                           drv_dataset_hmc_io_dynamic_forcing.py:[945    - collect_filename    ()]
# 2021-01-29 17:03:23,652 hmc_logger   INFO      -------> Type FOR ... SKIPPED. Datasets is empty                                drv_dataset_hmc_io_dynamic_forcing.py:[1111   - collect_filename    ()]
# 2021-01-29 17:03:23,666 hmc_logger   INFO      ------> Collect TimeSeries source filename(s) ... DONE                          drv_dataset_hmc_io_dynamic_forcing.py:[1145   - collect_filename    ()]
# 2021-01-29 17:03:23,667 hmc_logger   INFO      ------> Collect Gridded model filename(s) ...                                   drv_dataset_hmc_io_dynamic_forcing.py:[1152   - collect_filename    ()]
# 2021-01-29 17:03:23,695 hmc_logger   INFO      ------> Collect Gridded model filename(s) ... DONE                              drv_dataset_hmc_io_dynamic_forcing.py:[1276   - collect_filename    ()]
# 2021-01-29 17:03:23,696 hmc_logger   INFO      ------> Collect Point model filename(s) ...                                     drv_dataset_hmc_io_dynamic_forcing.py:[1152   - collect_filename    ()]
# 2021-01-29 17:03:23,717 hmc_logger   INFO      ------> Collect Point model filename(s) ... DONE                                drv_dataset_hmc_io_dynamic_forcing.py:[1276   - collect_filename    ()]
# 2021-01-29 17:03:23,719 hmc_logger   INFO      ------> Collect TimeSeries model filename(s) ...                                drv_dataset_hmc_io_dynamic_forcing.py:[1152   - collect_filename    ()]
# 2021-01-29 17:03:23,725 hmc_logger   INFO      ------> Collect TimeSeries model filename(s) ... DONE                           drv_dataset_hmc_io_dynamic_forcing.py:[1276   - collect_filename    ()]
# 2021-01-29 17:03:23,726 hmc_logger   INFO      -----> Run deterministic ... DONE                                               drv_dataset_hmc_base_source.py:[492    - organize_data_dynamic()]
# 2021-01-29 17:03:23,728 hmc_logger   INFO      ----> Organize dynamic datasets ... DONE                                        drv_dataset_hmc_base_source.py:[495    - organize_data_dynamic()]
# 2021-01-29 17:03:23,728 hmc_logger   INFO      ----> Analyze restart datasets for datatype ARCHIVE ...                         drv_dataset_hmc_base_source.py:[217    - analyze_data_dynamic_restart()]
# 2021-01-29 17:03:23,730 hmc_logger   INFO      -----> Run deterministic ...                                                    drv_dataset_hmc_base_source.py:[233    - analyze_data_dynamic_restart()]
# 2021-01-29 17:03:23,732 hmc_logger   INFO      ------> Datasets Gridded ...                                                    drv_dataset_hmc_base_source.py:[262    - analyze_data_dynamic_restart()]
# 2021-01-29 17:03:23,733 hmc_logger   INFO      -------> Collect ALL source datasets ...                                        drv_dataset_hmc_io_dynamic_forcing.py:[817    - collect_data        ()]
# 2021-01-29 17:03:23,920 hmc_logger   INFO      --------> Variable ALL ...                                                      drv_dataset_hmc_io_type.py:[219    - read_filename_dynamic()]
# 2021-01-29 17:03:23,921 hmc_logger   INFO      ---------> TimePeriod 2021-01-26 23:00:00 :: 2021-01-26 23:00:00 ...            drv_dataset_hmc_io_type.py:[243    - read_filename_dynamic()]
# 2021-01-29 17:03:27,615 hmc_logger   INFO      ---------> TimePeriod 2021-01-26 23:00:00 :: 2021-01-26 23:00:00 ... DONE       drv_dataset_hmc_io_type.py:[389    - read_filename_dynamic()]
# 2021-01-29 17:03:27,617 hmc_logger   INFO      --------> Variable ALL ... DONE                                                 drv_dataset_hmc_io_type.py:[399    - read_filename_dynamic()]
# 2021-01-29 17:03:27,618 hmc_logger   INFO      --------> Variable list: ['VTot', 'VRet', 'HydroLevel', 'Routing', 'DFE', 'WTLevel', 'LST', 'Tmk', 'T24', 'WS', 'SWE', 'RhoS', 'AlbedoS', 'AgeS', 'T_1Days', 'T_5Days'] with 16 items drv_dataset_hmc_io_dynamic_forcing.py:[875    - collect_data        ()]
# 2021-01-29 17:03:27,619 hmc_logger   INFO      -------> Collect ALL source datasets ... DONE                                   drv_dataset_hmc_io_dynamic_forcing.py:[895    - collect_data        ()]
# 2021-01-29 17:03:27,620 hmc_logger   INFO      -------> Organize gridded datasets ...                                          drv_dataset_hmc_io_dynamic_forcing.py:[531    - organize_data       ()]
# 2021-01-29 17:03:27,621 hmc_logger   INFO      --------> Organize VTot datasets ...                                            drv_dataset_hmc_io_dynamic_forcing.py:[544    - organize_data       ()]
# 2021-01-29 17:03:27,624 hmc_logger   INFO      --------> VTot datasets and terrain datasets have the same dimensions found by using the automatic detection drv_dataset_hmc_io_dynamic_forcing.py:[631    - organize_data       ()]
# 2021-01-29 17:03:28,852 hmc_logger   INFO      --------> Organize VTot datasets ... DONE                                       drv_dataset_hmc_io_dynamic_forcing.py:[697    - organize_data       ()]
# 2021-01-29 17:03:28,864 hmc_logger   INFO      --------> Organize VRet datasets ...                                            drv_dataset_hmc_io_dynamic_forcing.py:[544    - organize_data       ()]
# 2021-01-29 17:03:28,868 hmc_logger   INFO      --------> VRet datasets and terrain datasets have the same dimensions found by using the automatic detection drv_dataset_hmc_io_dynamic_forcing.py:[631    - organize_data       ()]
# 2021-01-29 17:03:28,919 hmc_logger   INFO      --------> Organize VRet datasets ... DONE                                       drv_dataset_hmc_io_dynamic_forcing.py:[697    - organize_data       ()]
# 2021-01-29 17:03:28,948 hmc_logger   INFO      --------> Organize HydroLevel datasets ...                                      drv_dataset_hmc_io_dynamic_forcing.py:[544    - organize_data       ()]
# 2021-01-29 17:03:28,949 hmc_logger   INFO      --------> Organize HydroLevel datasets ... SKIPPED. Variable is not selected for analysis. drv_dataset_hmc_io_dynamic_forcing.py:[739    - organize_data       ()]
# 2021-01-29 17:03:28,950 hmc_logger   INFO      --------> Organize Routing datasets ...                                         drv_dataset_hmc_io_dynamic_forcing.py:[544    - organize_data       ()]
# 2021-01-29 17:03:28,954 hmc_logger   INFO      --------> Routing datasets and terrain datasets have the same dimensions found by using the automatic detection drv_dataset_hmc_io_dynamic_forcing.py:[631    - organize_data       ()]
# 2021-01-29 17:03:29,012 hmc_logger   INFO      --------> Organize Routing datasets ... DONE                                    drv_dataset_hmc_io_dynamic_forcing.py:[697    - organize_data       ()]
# 2021-01-29 17:03:29,050 hmc_logger   INFO      --------> Organize DFE datasets ...                                             drv_dataset_hmc_io_dynamic_forcing.py:[544    - organize_data       ()]
# 2021-01-29 17:03:29,053 hmc_logger   INFO      --------> DFE datasets and terrain datasets have the same dimensions found by using the automatic detection drv_dataset_hmc_io_dynamic_forcing.py:[631    - organize_data       ()]
# 2021-01-29 17:03:29,090 hmc_logger   INFO      --------> Organize DFE datasets ... DONE                                        drv_dataset_hmc_io_dynamic_forcing.py:[697    - organize_data       ()]
# 2021-01-29 17:03:29,127 hmc_logger   INFO      --------> Organize WTLevel datasets ...                                         drv_dataset_hmc_io_dynamic_forcing.py:[544    - organize_data       ()]
# 2021-01-29 17:03:29,133 hmc_logger   INFO      --------> WTLevel datasets and terrain datasets have the same dimensions found by using the automatic detection drv_dataset_hmc_io_dynamic_forcing.py:[631    - organize_data       ()]
# 2021-01-29 17:03:29,179 hmc_logger   INFO      --------> Organize WTLevel datasets ... DONE                                    drv_dataset_hmc_io_dynamic_forcing.py:[697    - organize_data       ()]
# 2021-01-29 17:03:29,215 hmc_logger   INFO      --------> Organize LST datasets ...                                             drv_dataset_hmc_io_dynamic_forcing.py:[544    - organize_data       ()]
# 2021-01-29 17:03:29,219 hmc_logger   INFO      --------> LST datasets and terrain datasets have the same dimensions found by using the automatic detection drv_dataset_hmc_io_dynamic_forcing.py:[631    - organize_data       ()]
# 2021-01-29 17:03:29,254 hmc_logger   INFO      --------> Organize LST datasets ... DONE                                        drv_dataset_hmc_io_dynamic_forcing.py:[697    - organize_data       ()]
# 2021-01-29 17:03:29,288 hmc_logger   INFO      --------> Organize Tmk datasets ...                                             drv_dataset_hmc_io_dynamic_forcing.py:[544    - organize_data       ()]
# 2021-01-29 17:03:29,289 hmc_logger   INFO      --------> Organize Tmk datasets ... SKIPPED. Variable is not selected for analysis. drv_dataset_hmc_io_dynamic_forcing.py:[739    - organize_data       ()]
# 2021-01-29 17:03:29,293 hmc_logger   INFO      --------> Organize T24 datasets ...                                             drv_dataset_hmc_io_dynamic_forcing.py:[544    - organize_data       ()]
# 2021-01-29 17:03:29,294 hmc_logger   INFO      --------> Organize T24 datasets ... SKIPPED. Variable is not selected for analysis. drv_dataset_hmc_io_dynamic_forcing.py:[739    - organize_data       ()]
# 2021-01-29 17:03:29,297 hmc_logger   INFO      --------> Organize WS datasets ...                                              drv_dataset_hmc_io_dynamic_forcing.py:[544    - organize_data       ()]
# 2021-01-29 17:03:29,299 hmc_logger   INFO      --------> Organize WS datasets ... SKIPPED. Variable is not selected for analysis. drv_dataset_hmc_io_dynamic_forcing.py:[739    - organize_data       ()]
# 2021-01-29 17:03:29,300 hmc_logger   INFO      --------> Organize SWE datasets ...                                             drv_dataset_hmc_io_dynamic_forcing.py:[544    - organize_data       ()]
# 2021-01-29 17:03:29,301 hmc_logger   INFO      --------> Organize SWE datasets ... SKIPPED. Variable is not selected for analysis. drv_dataset_hmc_io_dynamic_forcing.py:[739    - organize_data       ()]
# 2021-01-29 17:03:29,303 hmc_logger   INFO      --------> Organize RhoS datasets ...                                            drv_dataset_hmc_io_dynamic_forcing.py:[544    - organize_data       ()]
# 2021-01-29 17:03:29,305 hmc_logger   INFO      --------> Organize RhoS datasets ... SKIPPED. Variable is not selected for analysis. drv_dataset_hmc_io_dynamic_forcing.py:[739    - organize_data       ()]
# 2021-01-29 17:03:29,306 hmc_logger   INFO      --------> Organize AlbedoS datasets ...                                         drv_dataset_hmc_io_dynamic_forcing.py:[544    - organize_data       ()]
# 2021-01-29 17:03:29,307 hmc_logger   INFO      --------> Organize AlbedoS datasets ... SKIPPED. Variable is not selected for analysis. drv_dataset_hmc_io_dynamic_forcing.py:[739    - organize_data       ()]
# 2021-01-29 17:03:29,308 hmc_logger   INFO      --------> Organize AgeS datasets ...                                            drv_dataset_hmc_io_dynamic_forcing.py:[544    - organize_data       ()]
# 2021-01-29 17:03:29,309 hmc_logger   INFO      --------> Organize AgeS datasets ... SKIPPED. Variable is not selected for analysis. drv_dataset_hmc_io_dynamic_forcing.py:[739    - organize_data       ()]
# 2021-01-29 17:03:29,310 hmc_logger   INFO      --------> Organize T_1Days datasets ...                                         drv_dataset_hmc_io_dynamic_forcing.py:[544    - organize_data       ()]
# 2021-01-29 17:03:29,311 hmc_logger   INFO      --------> Organize T_1Days datasets ... SKIPPED. Variable is not selected for analysis. drv_dataset_hmc_io_dynamic_forcing.py:[739    - organize_data       ()]
# 2021-01-29 17:03:29,313 hmc_logger   INFO      --------> Organize T_5Days datasets ...                                         drv_dataset_hmc_io_dynamic_forcing.py:[544    - organize_data       ()]
# 2021-01-29 17:03:29,314 hmc_logger   INFO      --------> Organize T_5Days datasets ... SKIPPED. Variable is not selected for analysis. drv_dataset_hmc_io_dynamic_forcing.py:[739    - organize_data       ()]
# 2021-01-29 17:03:29,315 hmc_logger   INFO      -------> Organize gridded datasets ... DONE                                     drv_dataset_hmc_io_dynamic_forcing.py:[741    - organize_data       ()]
# 2021-01-29 17:03:29,316 hmc_logger   INFO      -------> Freeze data ...                                                        drv_dataset_hmc_io_dynamic_forcing.py:[331    - freeze_data         ()]
# 2021-01-29 17:03:29,337 hmc_logger   INFO      -------> Freeze data ... DONE                                                   drv_dataset_hmc_io_dynamic_forcing.py:[425    - freeze_data         ()]
# 2021-01-29 17:03:29,339 hmc_logger   INFO      -------> Copy data ...                                                          drv_dataset_hmc_io_dynamic_forcing.py:[223    - copy_data           ()]
# 2021-01-29 17:03:29,340 hmc_logger   INFO      --------> Variable ALL ...                                                      drv_dataset_hmc_io_dynamic_forcing.py:[261    - copy_data           ()]
# 2021-01-29 17:03:29,371 hmc_logger   INFO      --------> Variable ALL ... DONE                                                 drv_dataset_hmc_io_dynamic_forcing.py:[323    - copy_data           ()]
# 2021-01-29 17:03:29,372 hmc_logger   INFO      -------> Copy data ... DONE                                                     drv_dataset_hmc_io_dynamic_forcing.py:[326    - copy_data           ()]
# 2021-01-29 17:03:29,376 hmc_logger   INFO      ------> Datasets Gridded ... DONE                                               drv_dataset_hmc_base_source.py:[305    - analyze_data_dynamic_restart()]
# 2021-01-29 17:03:29,377 hmc_logger   INFO      ------> Datasets Point ...                                                      drv_dataset_hmc_base_source.py:[262    - analyze_data_dynamic_restart()]
# 2021-01-29 17:03:29,378 hmc_logger   INFO      -------> Collect ALL source datasets ...                                        drv_dataset_hmc_io_dynamic_forcing.py:[817    - collect_data        ()]
# 2021-01-29 17:03:29,382 hmc_logger   INFO      --------> Variable ALL ...                                                      drv_dataset_hmc_io_type.py:[219    - read_filename_dynamic()]
# 2021-01-29 17:03:29,383 hmc_logger   INFO      ---------> TimePeriod 2021-01-26 23:00:00 :: 2021-01-26 23:00:00 ...            drv_dataset_hmc_io_type.py:[243    - read_filename_dynamic()]
# 2021-01-29 17:03:29,435 hmc_logger   INFO      ---------> TimePeriod 2021-01-26 23:00:00 :: 2021-01-26 23:00:00 ... DONE       drv_dataset_hmc_io_type.py:[389    - read_filename_dynamic()]
# 2021-01-29 17:03:29,437 hmc_logger   INFO      --------> Variable ALL ... DONE                                                 drv_dataset_hmc_io_type.py:[399    - read_filename_dynamic()]
# 2021-01-29 17:03:29,439 hmc_logger   INFO      -------> Collect DamV source datasets ... DONE                                  drv_dataset_hmc_io_dynamic_forcing.py:[895    - collect_data        ()]
# 2021-01-29 17:03:29,470 hmc_logger   INFO      -------> Organize point and time-series datasets ...                            drv_dataset_hmc_io_dynamic_forcing.py:[750    - organize_data       ()]
# 2021-01-29 17:03:29,472 hmc_logger   INFO      --------> Organize DamV datasets ...                                            drv_dataset_hmc_io_dynamic_forcing.py:[763    - organize_data       ()]
# 2021-01-29 17:03:29,492 hmc_logger   INFO      --------> Organize DamV datasets ... DONE                                       drv_dataset_hmc_io_dynamic_forcing.py:[771    - organize_data       ()]
# 2021-01-29 17:03:29,499 hmc_logger   INFO      -------> Organize point and time-series datasets ... DONE                       drv_dataset_hmc_io_dynamic_forcing.py:[781    - organize_data       ()]
# 2021-01-29 17:03:29,515 hmc_logger   INFO      -------> Freeze data ...                                                        drv_dataset_hmc_io_dynamic_forcing.py:[331    - freeze_data         ()]
# 2021-01-29 17:03:29,544 hmc_logger   INFO      -------> Freeze data ... DONE                                                   drv_dataset_hmc_io_dynamic_forcing.py:[425    - freeze_data         ()]
# 2021-01-29 17:03:29,545 hmc_logger   INFO      -------> Copy data ...                                                          drv_dataset_hmc_io_dynamic_forcing.py:[223    - copy_data           ()]
# 2021-01-29 17:03:29,549 hmc_logger   INFO      --------> Variable ALL ...                                                      drv_dataset_hmc_io_dynamic_forcing.py:[261    - copy_data           ()]
# 2021-01-29 17:03:29,551 hmc_logger   INFO      --------> Variable ALL ... DONE                                                 drv_dataset_hmc_io_dynamic_forcing.py:[323    - copy_data           ()]
# 2021-01-29 17:03:29,552 hmc_logger   INFO      -------> Copy data ... DONE                                                     drv_dataset_hmc_io_dynamic_forcing.py:[326    - copy_data           ()]
# 2021-01-29 17:03:29,552 hmc_logger   INFO      ------> Datasets Point ... DONE                                                 drv_dataset_hmc_base_source.py:[305    - analyze_data_dynamic_restart()]
# 2021-01-29 17:03:29,556 hmc_logger   INFO      -----> Run deterministic ... DONE                                               drv_dataset_hmc_base_source.py:[317    - analyze_data_dynamic_restart()]
# 2021-01-29 17:03:29,558 hmc_logger   INFO      ----> Analyze restart datasets for datatype ARCHIVE ... DONE                    drv_dataset_hmc_base_source.py:[320    - analyze_data_dynamic_restart()]
# 2021-01-29 17:03:29,561 hmc_logger   INFO      ----> Analyze forcing datasets for datatype OBS ...                             drv_dataset_hmc_base_source.py:[332    - analyze_data_dynamic_forcing()]
# 2021-01-29 17:03:29,562 hmc_logger   INFO      -----> Run deterministic ...                                                    drv_dataset_hmc_base_source.py:[348    - analyze_data_dynamic_forcing()]
# 2021-01-29 17:03:29,568 hmc_logger   INFO      ------> Datasets Gridded ...                                                    drv_dataset_hmc_base_source.py:[383    - analyze_data_dynamic_forcing()]
# 2021-01-29 17:03:29,581 hmc_logger   INFO      -------> Collect Rain source datasets ...                                       drv_dataset_hmc_io_dynamic_forcing.py:[817    - collect_data        ()]
# 2021-01-29 17:03:31,072 hmc_logger   INFO      --------> Variable Rain ...                                                     drv_dataset_hmc_io_type.py:[219    - read_filename_dynamic()]
# 2021-01-29 17:03:31,074 hmc_logger   INFO      ---------> TimePeriod 2021-01-27 00:00:00 :: 2021-01-27 23:00:00 ...            drv_dataset_hmc_io_type.py:[243    - read_filename_dynamic()]
# 2021-01-29 17:03:32,281 hmc_logger   WARNING   ===> GeoX coord name used Longitude but found longitude in collected datasets   lib_data_io_nc.py:[225    - read_data           ()]
# 2021-01-29 17:03:32,283 hmc_logger   WARNING   ===> GeoY coord name used Latitude but found latitude in collected datasets     lib_data_io_nc.py:[244    - read_data           ()]
# 2021-01-29 17:03:33,380 hmc_logger   INFO      ---------> TimePeriod 2021-01-27 00:00:00 :: 2021-01-27 23:00:00 ... DONE       drv_dataset_hmc_io_type.py:[389    - read_filename_dynamic()]
# 2021-01-29 17:03:33,381 hmc_logger   INFO      --------> Variable Rain ... DONE                                                drv_dataset_hmc_io_type.py:[399    - read_filename_dynamic()]
# 2021-01-29 17:03:33,382 hmc_logger   INFO      --------> Variable list: ['Rain'] with 1 item                                   drv_dataset_hmc_io_dynamic_forcing.py:[864    - collect_data        ()]
# 2021-01-29 17:03:33,382 hmc_logger   INFO      -------> Collect Rain source datasets ... DONE                                  drv_dataset_hmc_io_dynamic_forcing.py:[895    - collect_data        ()]
# 2021-01-29 17:03:33,383 hmc_logger   INFO      -------> Collect AirTemperature source datasets ...                             drv_dataset_hmc_io_dynamic_forcing.py:[817    - collect_data        ()]
# 2021-01-29 17:03:33,387 hmc_logger   INFO      --------> Variable AirTemperature ...                                           drv_dataset_hmc_io_type.py:[219    - read_filename_dynamic()]
# 2021-01-29 17:03:33,389 hmc_logger   INFO      ---------> TimePeriod 2021-01-27 00:00:00 :: 2021-01-27 23:00:00 ...            drv_dataset_hmc_io_type.py:[243    - read_filename_dynamic()]
# 2021-01-29 17:03:34,569 hmc_logger   WARNING   ===> GeoX coord name used Longitude but found longitude in collected datasets   lib_data_io_nc.py:[225    - read_data           ()]
# 2021-01-29 17:03:34,570 hmc_logger   WARNING   ===> GeoY coord name used Latitude but found latitude in collected datasets     lib_data_io_nc.py:[244    - read_data           ()]
# 2021-01-29 17:03:35,673 hmc_logger   INFO      ---------> TimePeriod 2021-01-27 00:00:00 :: 2021-01-27 23:00:00 ... DONE       drv_dataset_hmc_io_type.py:[389    - read_filename_dynamic()]
# 2021-01-29 17:03:35,675 hmc_logger   INFO      --------> Variable AirTemperature ... DONE                                      drv_dataset_hmc_io_type.py:[399    - read_filename_dynamic()]
# 2021-01-29 17:03:35,677 hmc_logger   INFO      --------> Variable list: ['Air_Temperature'] with 1 item                        drv_dataset_hmc_io_dynamic_forcing.py:[864    - collect_data        ()]
# 2021-01-29 17:03:35,679 hmc_logger   WARNING   ===> Switch variable name in dataset from "Air_Temperature" to "AirTemperature" drv_dataset_hmc_io_dynamic_forcing.py:[871    - collect_data        ()]
# 2021-01-29 17:03:35,819 hmc_logger   INFO      -------> Collect AirTemperature source datasets ... DONE                        drv_dataset_hmc_io_dynamic_forcing.py:[895    - collect_data        ()]
# 2021-01-29 17:03:35,820 hmc_logger   INFO      -------> Collect Wind source datasets ...                                       drv_dataset_hmc_io_dynamic_forcing.py:[817    - collect_data        ()]
# 2021-01-29 17:03:35,822 hmc_logger   INFO      --------> Variable Wind ...                                                     drv_dataset_hmc_io_type.py:[219    - read_filename_dynamic()]
# 2021-01-29 17:03:35,823 hmc_logger   INFO      ---------> TimePeriod 2021-01-27 00:00:00 :: 2021-01-27 23:00:00 ...            drv_dataset_hmc_io_type.py:[243    - read_filename_dynamic()]
# 2021-01-29 17:03:37,010 hmc_logger   WARNING   ===> GeoX coord name used Longitude but found longitude in collected datasets   lib_data_io_nc.py:[225    - read_data           ()]
# 2021-01-29 17:03:37,012 hmc_logger   WARNING   ===> GeoY coord name used Latitude but found latitude in collected datasets     lib_data_io_nc.py:[244    - read_data           ()]
# 2021-01-29 17:03:38,077 hmc_logger   INFO      ---------> TimePeriod 2021-01-27 00:00:00 :: 2021-01-27 23:00:00 ... DONE       drv_dataset_hmc_io_type.py:[389    - read_filename_dynamic()]
# 2021-01-29 17:03:38,079 hmc_logger   INFO      --------> Variable Wind ... DONE                                                drv_dataset_hmc_io_type.py:[399    - read_filename_dynamic()]
# 2021-01-29 17:03:38,083 hmc_logger   INFO      --------> Variable list: ['Wind'] with 1 item                                   drv_dataset_hmc_io_dynamic_forcing.py:[864    - collect_data        ()]
# 2021-01-29 17:03:38,259 hmc_logger   INFO      -------> Collect Wind source datasets ... DONE                                  drv_dataset_hmc_io_dynamic_forcing.py:[895    - collect_data        ()]
# 2021-01-29 17:03:38,260 hmc_logger   INFO      -------> Collect RelHumidity source datasets ...                                drv_dataset_hmc_io_dynamic_forcing.py:[817    - collect_data        ()]
# 2021-01-29 17:03:38,262 hmc_logger   INFO      --------> Variable RelHumidity ...                                              drv_dataset_hmc_io_type.py:[219    - read_filename_dynamic()]
# 2021-01-29 17:03:38,263 hmc_logger   INFO      ---------> TimePeriod 2021-01-27 00:00:00 :: 2021-01-27 23:00:00 ...            drv_dataset_hmc_io_type.py:[243    - read_filename_dynamic()]
# 2021-01-29 17:03:39,376 hmc_logger   WARNING   ===> GeoX coord name used Longitude but found longitude in collected datasets   lib_data_io_nc.py:[225    - read_data           ()]
# 2021-01-29 17:03:39,377 hmc_logger   WARNING   ===> GeoY coord name used Latitude but found latitude in collected datasets     lib_data_io_nc.py:[244    - read_data           ()]
# 2021-01-29 17:03:40,401 hmc_logger   INFO      ---------> TimePeriod 2021-01-27 00:00:00 :: 2021-01-27 23:00:00 ... DONE       drv_dataset_hmc_io_type.py:[389    - read_filename_dynamic()]
# 2021-01-29 17:03:40,402 hmc_logger   INFO      --------> Variable RelHumidity ... DONE                                         drv_dataset_hmc_io_type.py:[399    - read_filename_dynamic()]
# 2021-01-29 17:03:40,408 hmc_logger   INFO      --------> Variable list: ['Relative_Humidity'] with 1 item                      drv_dataset_hmc_io_dynamic_forcing.py:[864    - collect_data        ()]
# 2021-01-29 17:03:40,410 hmc_logger   WARNING   ===> Switch variable name in dataset from "Relative_Humidity" to "RelHumidity"  drv_dataset_hmc_io_dynamic_forcing.py:[871    - collect_data        ()]
# 2021-01-29 17:03:40,648 hmc_logger   INFO      -------> Collect RelHumidity source datasets ... DONE                           drv_dataset_hmc_io_dynamic_forcing.py:[895    - collect_data        ()]
# 2021-01-29 17:03:40,649 hmc_logger   INFO      -------> Collect IncRadiation source datasets ...                               drv_dataset_hmc_io_dynamic_forcing.py:[817    - collect_data        ()]
# 2021-01-29 17:03:40,651 hmc_logger   INFO      --------> Variable IncRadiation ...                                             drv_dataset_hmc_io_type.py:[219    - read_filename_dynamic()]
# 2021-01-29 17:03:40,652 hmc_logger   INFO      ---------> TimePeriod 2021-01-27 00:00:00 :: 2021-01-27 23:00:00 ...            drv_dataset_hmc_io_type.py:[243    - read_filename_dynamic()]
# 2021-01-29 17:03:41,746 hmc_logger   WARNING   ===> GeoX coord name used Longitude but found longitude in collected datasets   lib_data_io_nc.py:[225    - read_data           ()]
# 2021-01-29 17:03:41,748 hmc_logger   WARNING   ===> GeoY coord name used Latitude but found latitude in collected datasets     lib_data_io_nc.py:[244    - read_data           ()]
# 2021-01-29 17:03:42,792 hmc_logger   INFO      ---------> TimePeriod 2021-01-27 00:00:00 :: 2021-01-27 23:00:00 ... DONE       drv_dataset_hmc_io_type.py:[389    - read_filename_dynamic()]
# 2021-01-29 17:03:42,794 hmc_logger   INFO      --------> Variable IncRadiation ... DONE                                        drv_dataset_hmc_io_type.py:[399    - read_filename_dynamic()]
# 2021-01-29 17:03:42,799 hmc_logger   INFO      --------> Variable list: ['Incoming_Radiation'] with 1 item                     drv_dataset_hmc_io_dynamic_forcing.py:[864    - collect_data        ()]
# 2021-01-29 17:03:42,802 hmc_logger   WARNING   ===> Switch variable name in dataset from "Incoming_Radiation" to "IncRadiation" drv_dataset_hmc_io_dynamic_forcing.py:[871    - collect_data        ()]
# 2021-01-29 17:03:43,096 hmc_logger   INFO      -------> Collect IncRadiation source datasets ... DONE                          drv_dataset_hmc_io_dynamic_forcing.py:[895    - collect_data        ()]
# 2021-01-29 17:03:43,097 hmc_logger   INFO      -------> Collect AirPressure source datasets ...                                drv_dataset_hmc_io_dynamic_forcing.py:[817    - collect_data        ()]
# 2021-01-29 17:03:43,099 hmc_logger   INFO      --------> Variable AirPressure ...                                              drv_dataset_hmc_io_type.py:[219    - read_filename_dynamic()]
# 2021-01-29 17:03:43,100 hmc_logger   INFO      ---------> TimePeriod 2021-01-27 00:00:00 :: 2021-01-27 23:00:00 ...            drv_dataset_hmc_io_type.py:[243    - read_filename_dynamic()]
# 2021-01-29 17:03:44,183 hmc_logger   WARNING   ===> Variable AirPressure not available in loaded datasets!                     lib_data_io_nc.py:[196    - read_data           ()]
# 2021-01-29 17:03:44,185 hmc_logger   WARNING   ===> Dataset is None                                                            lib_data_io_nc.py:[450    - read_data           ()]
# 2021-01-29 17:03:44,203 hmc_logger   INFO      ---------> TimePeriod 2021-01-27 00:00:00 :: 2021-01-27 23:00:00 ... DONE       drv_dataset_hmc_io_type.py:[389    - read_filename_dynamic()]
# 2021-01-29 17:03:44,204 hmc_logger   INFO      --------> Variable AirPressure ... DONE                                         drv_dataset_hmc_io_type.py:[399    - read_filename_dynamic()]
# 2021-01-29 17:03:44,211 hmc_logger   INFO      -------> Collect AirPressure source datasets ... DONE                           drv_dataset_hmc_io_dynamic_forcing.py:[895    - collect_data        ()]
# 2021-01-29 17:03:44,212 hmc_logger   INFO      -------> Collect SnowHeight source datasets ...                                 drv_dataset_hmc_io_dynamic_forcing.py:[817    - collect_data        ()]
# 2021-01-29 17:03:44,214 hmc_logger   INFO      --------> Variable SnowHeight ...                                               drv_dataset_hmc_io_type.py:[219    - read_filename_dynamic()]
# 2021-01-29 17:03:44,215 hmc_logger   INFO      ---------> TimePeriod 2021-01-27 00:00:00 :: 2021-01-27 23:00:00 ...            drv_dataset_hmc_io_type.py:[243    - read_filename_dynamic()]
# 2021-01-29 17:03:45,330 hmc_logger   WARNING   ===> Variable SnowLevel not available in loaded datasets!                       lib_data_io_nc.py:[196    - read_data           ()]
# 2021-01-29 17:03:45,331 hmc_logger   WARNING   ===> Dataset is None                                                            lib_data_io_nc.py:[450    - read_data           ()]
# 2021-01-29 17:03:45,354 hmc_logger   INFO      ---------> TimePeriod 2021-01-27 00:00:00 :: 2021-01-27 23:00:00 ... DONE       drv_dataset_hmc_io_type.py:[389    - read_filename_dynamic()]
# ...
# 2021-01-29 17:04:40,195 hmc_logger   INFO      --------> Filename hmc.forcing-grid.202101281000.nc ... DONE                    drv_dataset_hmc_io_dynamic_forcing.py:[472    - dump_data           ()]
# 2021-01-29 17:04:40,197 hmc_logger   INFO      --------> Filename hmc.forcing-grid.202101281100.nc ...                         drv_dataset_hmc_io_dynamic_forcing.py:[466    - dump_data           ()]
# 2021-01-29 17:04:41,084 hmc_logger   INFO      --------> Filename hmc.forcing-grid.202101281100.nc ... DONE                    drv_dataset_hmc_io_dynamic_forcing.py:[472    - dump_data           ()]
# 2021-01-29 17:04:41,086 hmc_logger   INFO      --------> Filename hmc.forcing-grid.202101281200.nc ...                         drv_dataset_hmc_io_dynamic_forcing.py:[466    - dump_data           ()]
# 2021-01-29 17:04:41,931 hmc_logger   INFO      --------> Filename hmc.forcing-grid.202101281200.nc ... DONE                    drv_dataset_hmc_io_dynamic_forcing.py:[472    - dump_data           ()]
# 2021-01-29 17:04:41,932 hmc_logger   INFO      -------> Dump data ... DONE                                                     drv_dataset_hmc_io_dynamic_forcing.py:[483    - dump_data           ()]
# 2021-01-29 17:04:41,933 hmc_logger   INFO      -------> Zip data ...                                                           drv_dataset_hmc_io_dynamic_forcing.py:[486    - dump_data           ()]
# 2021-01-29 17:04:45,122 hmc_logger   INFO      -------> Zip data ... DONE                                                      drv_dataset_hmc_io_dynamic_forcing.py:[512    - dump_data           ()]
# 2021-01-29 17:04:45,123 hmc_logger   INFO      ------> Datasets Gridded ... DONE                                               drv_dataset_hmc_base_source.py:[432    - analyze_data_dynamic_forcing()]
# 2021-01-29 17:04:45,125 hmc_logger   INFO      ------> Datasets Point ...                                                      drv_dataset_hmc_base_source.py:[383    - analyze_data_dynamic_forcing()]
# 2021-01-29 17:04:45,130 hmc_logger   INFO      -------> Collect Discharge source datasets ...                                  drv_dataset_hmc_io_dynamic_forcing.py:[817    - collect_data        ()]
# 2021-01-29 17:04:45,134 hmc_logger   INFO      --------> Variable Discharge ...                                                drv_dataset_hmc_io_type.py:[219    - read_filename_dynamic()]
# 2021-01-29 17:04:45,135 hmc_logger   INFO      ---------> TimePeriod 2021-01-28 00:00:00 :: 2021-01-28 12:00:00 ...            drv_dataset_hmc_io_type.py:[243    - read_filename_dynamic()]
# 2021-01-29 17:04:45,506 hmc_logger   INFO      ---------> TimePeriod 2021-01-28 00:00:00 :: 2021-01-28 12:00:00 ... DONE       drv_dataset_hmc_io_type.py:[389    - read_filename_dynamic()]
# 2021-01-29 17:04:45,508 hmc_logger   INFO      --------> Variable Discharge ... DONE                                           drv_dataset_hmc_io_type.py:[399    - read_filename_dynamic()]
# 2021-01-29 17:04:45,509 hmc_logger   INFO      -------> Collect Discharge source datasets ... DONE                             drv_dataset_hmc_io_dynamic_forcing.py:[895    - collect_data        ()]
# 2021-01-29 17:04:45,509 hmc_logger   INFO      -------> Collect DamV source datasets ...                                       drv_dataset_hmc_io_dynamic_forcing.py:[817    - collect_data        ()]
# 2021-01-29 17:04:45,511 hmc_logger   INFO      --------> Variable DamV ...                                                     drv_dataset_hmc_io_type.py:[219    - read_filename_dynamic()]
# 2021-01-29 17:04:45,512 hmc_logger   WARNING   ===> Some/All filenames are not available!                                      drv_dataset_hmc_io_type.py:[392    - read_filename_dynamic()]
# 2021-01-29 17:04:45,513 hmc_logger   INFO      --------> Variable DamV ... DONE                                                drv_dataset_hmc_io_type.py:[399    - read_filename_dynamic()]
# 2021-01-29 17:04:45,514 hmc_logger   INFO      -------> Collect DamV source datasets ... DONE                                  drv_dataset_hmc_io_dynamic_forcing.py:[895    - collect_data        ()]
# 2021-01-29 17:04:45,517 hmc_logger   INFO      -------> Collect DamL source datasets ...                                       drv_dataset_hmc_io_dynamic_forcing.py:[817    - collect_data        ()]
# 2021-01-29 17:04:45,518 hmc_logger   INFO      --------> Variable DamL ...                                                     drv_dataset_hmc_io_type.py:[219    - read_filename_dynamic()]
# 2021-01-29 17:04:45,519 hmc_logger   WARNING   ===> Some/All filenames are not available!                                      drv_dataset_hmc_io_type.py:[392    - read_filename_dynamic()]
# 2021-01-29 17:04:45,520 hmc_logger   INFO      --------> Variable DamL ... DONE                                                drv_dataset_hmc_io_type.py:[399    - read_filename_dynamic()]
# 2021-01-29 17:04:45,522 hmc_logger   INFO      -------> Collect DamL source datasets ... DONE                                  drv_dataset_hmc_io_dynamic_forcing.py:[895    - collect_data        ()]
# 2021-01-29 17:04:45,537 hmc_logger   INFO      -------> Organize point and time-series datasets ...                            drv_dataset_hmc_io_dynamic_forcing.py:[750    - organize_data       ()]
# 2021-01-29 17:04:45,540 hmc_logger   INFO      --------> Organize Discharge datasets ...                                       drv_dataset_hmc_io_dynamic_forcing.py:[763    - organize_data       ()]
# 2021-01-29 17:04:45,676 hmc_logger   INFO      --------> Organize Discharge datasets ... DONE                                  drv_dataset_hmc_io_dynamic_forcing.py:[771    - organize_data       ()]
# 2021-01-29 17:04:45,688 hmc_logger   INFO      -------> Organize point and time-series datasets ... DONE                       drv_dataset_hmc_io_dynamic_forcing.py:[781    - organize_data       ()]
# 2021-01-29 17:04:45,702 hmc_logger   INFO      -------> Freeze data ...                                                        drv_dataset_hmc_io_dynamic_forcing.py:[331    - freeze_data         ()]
# 2021-01-29 17:04:45,768 hmc_logger   INFO      -------> Freeze data ... DONE                                                   drv_dataset_hmc_io_dynamic_forcing.py:[425    - freeze_data         ()]
# 2021-01-29 17:04:45,772 hmc_logger   INFO      -------> Copy data ...                                                          drv_dataset_hmc_io_dynamic_forcing.py:[223    - copy_data           ()]
# 2021-01-29 17:04:45,774 hmc_logger   INFO      --------> Variable Discharge ...                                                drv_dataset_hmc_io_dynamic_forcing.py:[261    - copy_data           ()]
# 2021-01-29 17:04:45,780 hmc_logger   INFO      --------> Variable Discharge ... DONE                                           drv_dataset_hmc_io_dynamic_forcing.py:[323    - copy_data           ()]
# 2021-01-29 17:04:45,780 hmc_logger   INFO      --------> Variable DamV ...                                                     drv_dataset_hmc_io_dynamic_forcing.py:[261    - copy_data           ()]
# 2021-01-29 17:04:45,782 hmc_logger   WARNING   ===> Copy file: ... FAILED. All files do not exist                              drv_dataset_hmc_io_dynamic_forcing.py:[321    - copy_data           ()]
# 2021-01-29 17:04:45,783 hmc_logger   INFO      --------> Variable DamV ... DONE                                                drv_dataset_hmc_io_dynamic_forcing.py:[323    - copy_data           ()]
# 2021-01-29 17:04:45,784 hmc_logger   INFO      --------> Variable DamL ...                                                     drv_dataset_hmc_io_dynamic_forcing.py:[261    - copy_data           ()]
# 2021-01-29 17:04:45,784 hmc_logger   WARNING   ===> Copy file: ... FAILED. All files do not exist                              drv_dataset_hmc_io_dynamic_forcing.py:[321    - copy_data           ()]
# 2021-01-29 17:04:45,787 hmc_logger   INFO      --------> Variable DamL ... DONE                                                drv_dataset_hmc_io_dynamic_forcing.py:[323    - copy_data           ()]
# 2021-01-29 17:04:45,788 hmc_logger   INFO      -------> Copy data ... DONE                                                     drv_dataset_hmc_io_dynamic_forcing.py:[326    - copy_data           ()]
# 2021-01-29 17:04:45,789 hmc_logger   INFO      ------> Datasets Point ... DONE                                                 drv_dataset_hmc_base_source.py:[432    - analyze_data_dynamic_forcing()]
# 2021-01-29 17:04:45,790 hmc_logger   INFO      ------> Datasets TimeSeries ...                                                 drv_dataset_hmc_base_source.py:[383    - analyze_data_dynamic_forcing()]
# 2021-01-29 17:04:45,792 hmc_logger   INFO      -------> Collect DamQ source datasets ...                                       drv_dataset_hmc_io_dynamic_forcing.py:[817    - collect_data        ()]
# 2021-01-29 17:04:45,793 hmc_logger   INFO      --------> Variable DamQ ...                                                     drv_dataset_hmc_io_type.py:[219    - read_filename_dynamic()]
# 2021-01-29 17:04:45,794 hmc_logger   INFO      ---------> TimePeriod 2021-01-28 00:00:00 :: 2021-01-28 12:00:00 ...            drv_dataset_hmc_io_type.py:[243    - read_filename_dynamic()]
# 2021-01-29 17:04:45,799 hmc_logger   INFO      ---------> TimePeriod 2021-01-28 00:00:00 :: 2021-01-28 12:00:00 ... DONE       drv_dataset_hmc_io_type.py:[389    - read_filename_dynamic()]
# 2021-01-29 17:04:45,800 hmc_logger   INFO      --------> Variable DamQ ... DONE                                                drv_dataset_hmc_io_type.py:[399    - read_filename_dynamic()]
# 2021-01-29 17:04:45,801 hmc_logger   INFO      -------> Collect DamQ source datasets ... DONE                                  drv_dataset_hmc_io_dynamic_forcing.py:[895    - collect_data        ()]
# 2021-01-29 17:04:45,802 hmc_logger   INFO      -------> Collect IntakeQ source datasets ...                                    drv_dataset_hmc_io_dynamic_forcing.py:[817    - collect_data        ()]
# 2021-01-29 17:04:45,803 hmc_logger   INFO      --------> Variable IntakeQ ...                                                  drv_dataset_hmc_io_type.py:[219    - read_filename_dynamic()]
# 2021-01-29 17:04:45,805 hmc_logger   INFO      ---------> TimePeriod 2021-01-28 00:00:00 :: 2021-01-28 12:00:00 ...            drv_dataset_hmc_io_type.py:[243    - read_filename_dynamic()]
# 2021-01-29 17:04:45,808 hmc_logger   INFO      ---------> TimePeriod 2021-01-28 00:00:00 :: 2021-01-28 12:00:00 ... DONE       drv_dataset_hmc_io_type.py:[389    - read_filename_dynamic()]
# 2021-01-29 17:04:45,810 hmc_logger   INFO      --------> Variable IntakeQ ... DONE                                             drv_dataset_hmc_io_type.py:[399    - read_filename_dynamic()]
# 2021-01-29 17:04:45,812 hmc_logger   INFO      -------> Collect IntakeQ source datasets ... DONE                               drv_dataset_hmc_io_dynamic_forcing.py:[895    - collect_data        ()]
# 2021-01-29 17:04:45,816 hmc_logger   INFO      -------> Organize point and time-series datasets ...                            drv_dataset_hmc_io_dynamic_forcing.py:[750    - organize_data       ()]
# 2021-01-29 17:04:45,819 hmc_logger   INFO      --------> Organize DamQ datasets ...                                            drv_dataset_hmc_io_dynamic_forcing.py:[763    - organize_data       ()]
# 2021-01-29 17:04:45,820 hmc_logger   INFO      --------> Organize DamQ datasets ... DONE                                       drv_dataset_hmc_io_dynamic_forcing.py:[771    - organize_data       ()]
# 2021-01-29 17:04:45,822 hmc_logger   INFO      --------> Organize IntakeQ datasets ...                                         drv_dataset_hmc_io_dynamic_forcing.py:[763    - organize_data       ()]
# 2021-01-29 17:04:45,823 hmc_logger   INFO      --------> Organize IntakeQ datasets ... DONE                                    drv_dataset_hmc_io_dynamic_forcing.py:[771    - organize_data       ()]
# 2021-01-29 17:04:45,827 hmc_logger   INFO      -------> Organize point and time-series datasets ... DONE                       drv_dataset_hmc_io_dynamic_forcing.py:[781    - organize_data       ()]
# 2021-01-29 17:04:45,832 hmc_logger   INFO      -------> Freeze data ...                                                        drv_dataset_hmc_io_dynamic_forcing.py:[331    - freeze_data         ()]
# 2021-01-29 17:04:45,833 hmc_logger   INFO      -------> Freeze data ... DONE                                                   drv_dataset_hmc_io_dynamic_forcing.py:[425    - freeze_data         ()]
# 2021-01-29 17:04:45,834 hmc_logger   INFO      -------> Copy data ...                                                          drv_dataset_hmc_io_dynamic_forcing.py:[223    - copy_data           ()]
# 2021-01-29 17:04:45,835 hmc_logger   INFO      --------> Variable DamQ ...                                                     drv_dataset_hmc_io_dynamic_forcing.py:[261    - copy_data           ()]
# 2021-01-29 17:04:45,836 hmc_logger   WARNING   ===> Copy file:  FAILED. File does not exist!                                   drv_dataset_hmc_io_dynamic_forcing.py:[319    - copy_data           ()]
# 2021-01-29 17:04:45,837 hmc_logger   INFO      --------> Variable DamQ ... DONE                                                drv_dataset_hmc_io_dynamic_forcing.py:[323    - copy_data           ()]
# 2021-01-29 17:04:45,842 hmc_logger   INFO      --------> Variable IntakeQ ...                                                  drv_dataset_hmc_io_dynamic_forcing.py:[261    - copy_data           ()]
# 2021-01-29 17:04:45,844 hmc_logger   WARNING   ===> Copy file:  FAILED. File does not exist!                                   drv_dataset_hmc_io_dynamic_forcing.py:[319    - copy_data           ()]
# 2021-01-29 17:04:45,844 hmc_logger   INFO      --------> Variable IntakeQ ... DONE                                             drv_dataset_hmc_io_dynamic_forcing.py:[323    - copy_data           ()]
# 2021-01-29 17:04:45,845 hmc_logger   INFO      -------> Copy data ... DONE                                                     drv_dataset_hmc_io_dynamic_forcing.py:[326    - copy_data           ()]
# 2021-01-29 17:04:45,847 hmc_logger   INFO      ------> Datasets TimeSeries ... DONE                                            drv_dataset_hmc_base_source.py:[432    - analyze_data_dynamic_forcing()]
# 2021-01-29 17:04:45,849 hmc_logger   INFO      -----> Run deterministic ... DONE                                               drv_dataset_hmc_base_source.py:[445    - analyze_data_dynamic_forcing()]
# 2021-01-29 17:04:45,851 hmc_logger   INFO      ----> Analyze forcing datasets for datatype OBS ... DONE                        drv_dataset_hmc_base_source.py:[448    - analyze_data_dynamic_forcing()]
# 2021-01-29 17:04:45,853 hmc_logger   INFO      ----> Analyze forcing datasets for datatype FOR ...                             drv_dataset_hmc_base_source.py:[332    - analyze_data_dynamic_forcing()]
# 2021-01-29 17:04:45,855 hmc_logger   INFO      -----> Run deterministic ...                                                    drv_dataset_hmc_base_source.py:[348    - analyze_data_dynamic_forcing()]
# 2021-01-29 17:04:45,859 hmc_logger   INFO      -----> Run deterministic ... DONE                                               drv_dataset_hmc_base_source.py:[445    - analyze_data_dynamic_forcing()]
# 2021-01-29 17:04:45,860 hmc_logger   INFO      ----> Analyze forcing datasets for datatype FOR ... DONE                        drv_dataset_hmc_base_source.py:[448    - analyze_data_dynamic_forcing()]
# 2021-01-29 17:04:45,863 hmc_logger   INFO      #### Configure dynamic source datasets ... DONE                                 cpl_hmc_builder.py:[154    - configure_dynamic_datasets()]
#  ==> Organize the model dynamic datasets ... DONE

# %% [markdown]
# ### **Run the instance of the Continuum model**
# - Configure the runner model class

# %%
# Info
print(' ==> Configure the model runner class ... ')

# Set the verbose debug level
log_stream.setLevel(logging.ERROR)

# Configure model runner class
driver_hmc_runner = ModelRunner(time_info=time_info_collections, run_info=run_info_collections,
                                command_line_info=run_cline_collections,
                                obj_args=driver_hmc_initializer.obj_args,
                                obj_ancillary=driver_hmc_initializer.obj_ancillary)

# Info
print(' ==> Configure the model runner class ... DONE')
# Out:
#  ==> Configure the model runner class ...
#  ==> Configure the model runner class ... DONE

# %% [markdown]
# - Execute the instance of the model

# %%
# Info
print(' ==> Execute the model run ... ')

# Set the verbose debug level
log_stream.setLevel(logging.INFO)

# Configure the model execution
driver_hmc_runner.configure_execution(ancillary_datasets_collections)

# Info
print(' ==> Execute the model run ... DONE')
# Out:
# 2021-01-29 17:08:43,484 hmc_logger   INFO      #### Configure execution ...                                                    cpl_hmc_runner.py:[107    - configure_execution ()]
# 2021-01-29 17:08:43,486 hmc_logger   INFO      ------> Process execution: /home/fabio/fp_run_hmc/jupyter_ws/exec/HMC_Model_V3_jupyter_ws.x /home/fabio/fp_run_hmc/jupyter_ws/exec/marche.info.txt ...  lib_utils_process.py:[42     - exec_process        ()]
#  ==> Execute the model run ...
# 2021-01-29 17:08:44,558 hmc_logger   INFO     ----> ************************************************************************   lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:44,561 hmc_logger   INFO     ---->  Hydrological Model Continuum (Version: 3.1.3)                             lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:44,562 hmc_logger   INFO     ---->  Author(s): Delogu F., Silvestro F., Gabellani S., Basso V., Libertino A., Ercolani G. lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:44,563 hmc_logger   INFO     ---->  Release Date: 2020/10/28                                                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:44,564 hmc_logger   INFO     ----> ************************************************************************   lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:44,583 hmc_logger   INFO     ---->  PARAMETER(S) DEFAULT INFO --- dUc:   0.500000000 - dUh:    1.50000000 dCt:   0.500000000 dCf:    1.99999996E-02 lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:44,585 hmc_logger   INFO     ---->  SIMULATION START :: Time: 2021-01-29 17:08:44.502                         lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:47,215 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: GetArcGrid ---> file not found (filename: /home/fabio/fp_labs_datasets/data_static/gridded/marche.wt_max.txt) lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:47,216 hmc_logger   INFO     ------> WARNING:  WT maximum data not found. Initializing WT maximum data with default values. lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:47,356 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: GetArcGrid ---> file not found (filename: /home/fabio/fp_labs_datasets/data_static/gridded/marche.ct_wp.txt) lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:47,358 hmc_logger   INFO     ------> WARNING:  Permanent wilting point data not found. Initializing with default value 0.4*Ct. lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:48,214 hmc_logger   INFO     ------> WARNING:  WaterSources not activated. CoeffWS is null.                   lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:48,218 hmc_logger   INFO     ------> WARNING:  Channel Network activated. Initializing SectionWidth with undefined values. lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:48,223 hmc_logger   INFO     ------> WARNING:  Fracturing not activated. Initializing Fracturing with zero values. lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:48,224 hmc_logger   INFO     ------> WARNING:  Flooding not activated.                                        lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:48,253 hmc_logger   INFO     ------> WARNING:  CtWP values are equal to 0.0 in       127010 pixels over domain. Initialize with default value: 0.4*Ct. lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:48,467 hmc_logger   INFO     ------> WARNING:  No dam storage curve file found: /home/fabio/fp_labs_datasets/data_static/point/#Nome (Dam: Comunanza) lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:48,468 hmc_logger   INFO     ------> WARNING:  No dam storage curve file found: /home/fabio/fp_labs_datasets/data_static/point/#Nome (Dam: SanRuffino) lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:48,707 hmc_logger   INFO     ---->  Get filename (restart gridded): /home/fabio/fp_run_hmc/jupyter_ws/restart/hmc.state-grid.202101262300.nc ... lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,318 hmc_logger   INFO     ---->  Get filename (restart gridded): /home/fabio/fp_run_hmc/jupyter_ws/restart/hmc.state-grid.202101262300.nc ... OK lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,319 hmc_logger   INFO     ---->  Data :: Restart gridded :: NetCDF :: All variable(s) are loaded!          lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,519 hmc_logger   INFO     ---->  Get (restart point) at time 2021-01-26_23:00:00 ...                       lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,520 hmc_logger   INFO     ---->  Get (restart point) at time 2021-01-26_23:00:00 ... OK                    lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,521 hmc_logger   INFO     ---->  Data :: Restart point :: ASCII :: All variable(s) are loaded!             lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,523 hmc_logger   INFO     ---->  ===== TIME STEP START :: Date, iT, iNTime, iDt, Clock :: 2021-01-27_00:00:00            1           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,524 hmc_logger   INFO     ---->  STEP CLOCK START :: Time: 2021-01-29 17:08:49.519                         lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,543 hmc_logger   INFO     ------> WARNING:  No forcing point ASCII data found (dam volume): /home/fabio/fp_run_hmc/jupyter_ws/forcing/point/damv.db.202101270000.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,544 hmc_logger   INFO     ------> WARNING:  No forcing time-series ASCII data found (plant): /home/fabio/fp_run_hmc/jupyter_ws/forcing/time_series/hmc.forcing-ts.plant_#File.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,546 hmc_logger   INFO     ------> WARNING:  No forcing time-series ASCII data found (plant): /home/fabio/fp_run_hmc/jupyter_ws/forcing/time_series/hmc.forcing-ts.plant_#File.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,547 hmc_logger   INFO     ------> WARNING:  No forcing time-series ASCII data found (plant): /home/fabio/fp_run_hmc/jupyter_ws/forcing/time_series/hmc.forcing-ts.plant_#File.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,549 hmc_logger   INFO     ------> WARNING:  No forcing time-series ASCII data found (plant): /home/fabio/fp_run_hmc/jupyter_ws/forcing/time_series/hmc.forcing-ts.plant_#File.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,550 hmc_logger   INFO     ------> WARNING:  No forcing time-series ASCII data found (plant): /home/fabio/fp_run_hmc/jupyter_ws/forcing/time_series/hmc.forcing-ts.plant_#File.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,552 hmc_logger   INFO     ------> WARNING:  Area cell for #File plant is undefined! Model will use a default value! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,554 hmc_logger   INFO     ------> WARNING:  No forcing time-series ASCII data found (plant): /home/fabio/fp_run_hmc/jupyter_ws/forcing/time_series/hmc.forcing-ts.plant_#File.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,557 hmc_logger   INFO     ------> WARNING:  No forcing time-series ASCII data found (plant): /home/fabio/fp_run_hmc/jupyter_ws/forcing/time_series/hmc.forcing-ts.plant_#File.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,558 hmc_logger   INFO     ------> WARNING:  No forcing time-series ASCII data found (plant): /home/fabio/fp_run_hmc/jupyter_ws/forcing/time_series/hmc.forcing-ts.plant_#File.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,559 hmc_logger   INFO     ------> WARNING:  No forcing time-series ASCII data found (plant): /home/fabio/fp_run_hmc/jupyter_ws/forcing/time_series/hmc.forcing-ts.plant_#File.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,560 hmc_logger   INFO     ------> WARNING:  No forcing time-series ASCII data found (plant): /home/fabio/fp_run_hmc/jupyter_ws/forcing/time_series/hmc.forcing-ts.plant_#File.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,561 hmc_logger   INFO     ------> WARNING:  No forcing time-series ASCII data found (plant): /home/fabio/fp_run_hmc/jupyter_ws/forcing/time_series/hmc.forcing-ts.plant_#File.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,561 hmc_logger   INFO     ------> WARNING:  No forcing time-series ASCII data found (plant): /home/fabio/fp_run_hmc/jupyter_ws/forcing/time_series/hmc.forcing-ts.plant_#File.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,562 hmc_logger   INFO     ------> WARNING:  No forcing time-series ASCII data found (plant): /home/fabio/fp_run_hmc/jupyter_ws/forcing/time_series/hmc.forcing-ts.plant_#File.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,563 hmc_logger   INFO     ------> WARNING:  No forcing time-series ASCII data found (plant): /home/fabio/fp_run_hmc/jupyter_ws/forcing/time_series/hmc.forcing-ts.plant_#File.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,746 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: AirPressure) lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,750 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for AirPressure! Variable initializes in default mode using Altitude values! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,752 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: Albedo) lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,753 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for Albedo! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,757 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: LAI)  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,761 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for LAI!   lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,763 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: FC)   lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,764 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for FC!    lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,836 hmc_logger   INFO     ------> WARNING:  All air pressure values are equal to 101.3 [kPa]! AirPressure will be initialized using altitude (DEM) information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,850 hmc_logger   INFO     ------> WARNING:  All LAI values are undefined! LAI will be initialized using monthly mean information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,855 hmc_logger   INFO     ------> WARNING:  Fractional vegetation Cover set equal to one!                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,859 hmc_logger   INFO     ------> WARNING:  All albedo values are undefined! Albedo will be initialized using monthly mean information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,865 hmc_logger   INFO     ------> WARNING:  No compressed updating netCDF data found: /home/fabio/fp_run_hmc/jupyter_ws/forcing/gridded/hmc.updating-grid.202101270000.nc.gz lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:49,890 hmc_logger   INFO     ------> WARNING:  All snow mask values are undefined! Check updating data! Snow physics is not activated! If Snow mask is provided by external file, check updating data! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:50,227 hmc_logger   INFO     ---->  Phys :: LSM :: IntegrationStep ::  900   [s]                              lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:50,229 hmc_logger   INFO     ---->  Phys :: LSM :: AvgValue ::  LST: 270.8      [K]  Rn:  -51.5     [W/m^2]  H:   -1.9     [W/m^2]  LE:    5.3     [W/m^2] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:50,259 hmc_logger   INFO     ---->  Phys :: EVT :: AvgValue ::  AE:  0.0085    [mm]  ET:  0.0076    [mm]  ET Tot:  0.0085    [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:50,310 hmc_logger   INFO     ---->  Phys :: Convolution :: IntegrationStep ::   24       [s]                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:08:50,312 hmc_logger   INFO     ---->  Phys :: Convolution :: MaxValue ::  Uc:  7.73498   [m/s]  Rain:  0.00000   [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:04,274 hmc_logger   INFO     ---->  Phys :: Convolution :: Discharge :: Q SecFirst:      26.27 [m^3/s] Q SecMax:     114.89 [m^3/s] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:07,502 hmc_logger   INFO     ---->  STEP CLOCK END :: Time: 2021-01-29 17:09:07.502                           lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:07,504 hmc_logger   INFO     ---->  ===== TIME STEP END :: Date, iT, iNTime, iDt :: 2021-01-27_00:00:00            1           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:07,505 hmc_logger   INFO     ---->  ===== TIME STEP START :: Date, iT, iNTime, iDt, Clock :: 2021-01-27_01:00:00            2           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:07,507 hmc_logger   INFO     ---->  STEP CLOCK START :: Time: 2021-01-29 17:09:07.503                         lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:07,508 hmc_logger   INFO     ------> WARNING:  No forcing point ASCII data found (dam volume): /home/fabio/fp_run_hmc/jupyter_ws/forcing/point/damv.db.202101270100.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:07,676 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: AirPressure) lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:07,678 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for AirPressure! Variable initializes in default mode using Altitude values! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:07,683 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: Albedo) lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:07,684 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for Albedo! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:07,689 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: LAI)  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:07,692 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for LAI!   lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:07,693 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: FC)   lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:07,694 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for FC!    lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:07,744 hmc_logger   INFO     ------> WARNING:  All air pressure values are equal to 101.3 [kPa]! AirPressure will be initialized using altitude (DEM) information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:07,756 hmc_logger   INFO     ------> WARNING:  All LAI values are undefined! LAI will be initialized using monthly mean information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:07,760 hmc_logger   INFO     ------> WARNING:  Fractional vegetation Cover set equal to one!                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:07,764 hmc_logger   INFO     ------> WARNING:  All albedo values are undefined! Albedo will be initialized using monthly mean information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:07,771 hmc_logger   INFO     ------> WARNING:  No compressed updating netCDF data found: /home/fabio/fp_run_hmc/jupyter_ws/forcing/gridded/hmc.updating-grid.202101270100.nc.gz lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:07,798 hmc_logger   INFO     ------> WARNING:  All snow mask values are undefined! Check updating data! Snow physics is not activated! If Snow mask is provided by external file, check updating data! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:08,182 hmc_logger   INFO     ---->  Phys :: LSM :: IntegrationStep ::  900   [s]                              lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:08,185 hmc_logger   INFO     ---->  Phys :: LSM :: AvgValue ::  LST: 270.1      [K]  Rn:  -48.9     [W/m^2]  H:   -2.5     [W/m^2]  LE:    4.3     [W/m^2] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:08,227 hmc_logger   INFO     ---->  Phys :: EVT :: AvgValue ::  AE:  0.0069    [mm]  ET:  0.0062    [mm]  ET Tot:  0.0153    [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:08,340 hmc_logger   INFO     ---->  Phys :: Convolution :: IntegrationStep ::   24       [s]                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:08,342 hmc_logger   INFO     ---->  Phys :: Convolution :: MaxValue ::  Uc:  7.58575   [m/s]  Rain:  0.00000   [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:21,660 hmc_logger   INFO     ---->  Phys :: Convolution :: Discharge :: Q SecFirst:      26.18 [m^3/s] Q SecMax:     114.27 [m^3/s] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:24,695 hmc_logger   INFO     ---->  STEP CLOCK END :: Time: 2021-01-29 17:09:24.695                           lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:24,697 hmc_logger   INFO     ---->  ===== TIME STEP END :: Date, iT, iNTime, iDt :: 2021-01-27_01:00:00            2           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:24,700 hmc_logger   INFO     ---->  ===== TIME STEP START :: Date, iT, iNTime, iDt, Clock :: 2021-01-27_02:00:00            3           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:24,702 hmc_logger   INFO     ---->  STEP CLOCK START :: Time: 2021-01-29 17:09:24.695                         lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:24,703 hmc_logger   INFO     ------> WARNING:  No forcing point ASCII data found (dam volume): /home/fabio/fp_run_hmc/jupyter_ws/forcing/point/damv.db.202101270200.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:24,867 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: AirPressure) lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:24,869 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for AirPressure! Variable initializes in default mode using Altitude values! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:24,874 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: Albedo) lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:24,877 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for Albedo! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:24,880 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: LAI)  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:24,884 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for LAI!   lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:24,885 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: FC)   lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:24,887 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for FC!    lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:24,938 hmc_logger   INFO     ------> WARNING:  All air pressure values are equal to 101.3 [kPa]! AirPressure will be initialized using altitude (DEM) information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:24,951 hmc_logger   INFO     ------> WARNING:  All LAI values are undefined! LAI will be initialized using monthly mean information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:24,956 hmc_logger   INFO     ------> WARNING:  Fractional vegetation Cover set equal to one!                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:24,959 hmc_logger   INFO     ------> WARNING:  All albedo values are undefined! Albedo will be initialized using monthly mean information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:24,966 hmc_logger   INFO     ------> WARNING:  No compressed updating netCDF data found: /home/fabio/fp_run_hmc/jupyter_ws/forcing/gridded/hmc.updating-grid.202101270200.nc.gz lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:24,991 hmc_logger   INFO     ------> WARNING:  All snow mask values are undefined! Check updating data! Snow physics is not activated! If Snow mask is provided by external file, check updating data! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:25,329 hmc_logger   INFO     ---->  Phys :: LSM :: IntegrationStep ::  900   [s]                              lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:25,330 hmc_logger   INFO     ---->  Phys :: LSM :: AvgValue ::  LST: 269.5      [K]  Rn:  -46.9     [W/m^2]  H:   -3.4     [W/m^2]  LE:    4.1     [W/m^2] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:25,361 hmc_logger   INFO     ---->  Phys :: EVT :: AvgValue ::  AE:  0.0065    [mm]  ET:  0.0059    [mm]  ET Tot:  0.0218    [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:25,430 hmc_logger   INFO     ---->  Phys :: Convolution :: IntegrationStep ::   24       [s]                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:25,432 hmc_logger   INFO     ---->  Phys :: Convolution :: MaxValue ::  Uc:  7.58688   [m/s]  Rain:  0.00000   [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:38,858 hmc_logger   INFO     ---->  Phys :: Convolution :: Discharge :: Q SecFirst:      25.80 [m^3/s] Q SecMax:     114.33 [m^3/s] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,075 hmc_logger   INFO     ---->  STEP CLOCK END :: Time: 2021-01-29 17:09:42.074                           lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,077 hmc_logger   INFO     ---->  ===== TIME STEP END :: Date, iT, iNTime, iDt :: 2021-01-27_02:00:00            3           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,081 hmc_logger   INFO     ---->  ===== TIME STEP START :: Date, iT, iNTime, iDt, Clock :: 2021-01-27_03:00:00            4           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,084 hmc_logger   INFO     ---->  STEP CLOCK START :: Time: 2021-01-29 17:09:42.075                         lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,089 hmc_logger   INFO     ------> WARNING:  No forcing point ASCII data found (dam volume): /home/fabio/fp_run_hmc/jupyter_ws/forcing/point/damv.db.202101270300.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,235 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: AirPressure) lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,240 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for AirPressure! Variable initializes in default mode using Altitude values! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,242 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: Albedo) lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,243 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for Albedo! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,246 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: LAI)  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,250 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for LAI!   lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,252 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: FC)   lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,253 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for FC!    lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,307 hmc_logger   INFO     ------> WARNING:  All air pressure values are equal to 101.3 [kPa]! AirPressure will be initialized using altitude (DEM) information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,320 hmc_logger   INFO     ------> WARNING:  All LAI values are undefined! LAI will be initialized using monthly mean information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,324 hmc_logger   INFO     ------> WARNING:  Fractional vegetation Cover set equal to one!                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,328 hmc_logger   INFO     ------> WARNING:  All albedo values are undefined! Albedo will be initialized using monthly mean information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,334 hmc_logger   INFO     ------> WARNING:  No compressed updating netCDF data found: /home/fabio/fp_run_hmc/jupyter_ws/forcing/gridded/hmc.updating-grid.202101270300.nc.gz lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,360 hmc_logger   INFO     ------> WARNING:  All snow mask values are undefined! Check updating data! Snow physics is not activated! If Snow mask is provided by external file, check updating data! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,704 hmc_logger   INFO     ---->  Phys :: LSM :: IntegrationStep ::  900   [s]                              lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,705 hmc_logger   INFO     ---->  Phys :: LSM :: AvgValue ::  LST: 268.9      [K]  Rn:  -44.8     [W/m^2]  H:   -4.4     [W/m^2]  LE:    4.1     [W/m^2] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,736 hmc_logger   INFO     ---->  Phys :: EVT :: AvgValue ::  AE:  0.0066    [mm]  ET:  0.0060    [mm]  ET Tot:  0.0284    [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,805 hmc_logger   INFO     ---->  Phys :: Convolution :: IntegrationStep ::   24       [s]                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:42,807 hmc_logger   INFO     ---->  Phys :: Convolution :: MaxValue ::  Uc:  7.56191   [m/s]  Rain:  0.00000   [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:09:57,565 hmc_logger   INFO     ---->  Phys :: Convolution :: Discharge :: Q SecFirst:      25.90 [m^3/s] Q SecMax:     112.55 [m^3/s] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:00,907 hmc_logger   INFO     ---->  STEP CLOCK END :: Time: 2021-01-29 17:10:00.907                           lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:00,909 hmc_logger   INFO     ---->  ===== TIME STEP END :: Date, iT, iNTime, iDt :: 2021-01-27_03:00:00            4           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:00,912 hmc_logger   INFO     ---->  ===== TIME STEP START :: Date, iT, iNTime, iDt, Clock :: 2021-01-27_04:00:00            5           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:00,913 hmc_logger   INFO     ---->  STEP CLOCK START :: Time: 2021-01-29 17:10:00.907                         lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:00,916 hmc_logger   INFO     ------> WARNING:  No forcing point ASCII data found (dam volume): /home/fabio/fp_run_hmc/jupyter_ws/forcing/point/damv.db.202101270400.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:01,123 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: AirPressure) lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:01,124 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for AirPressure! Variable initializes in default mode using Altitude values! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:01,125 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: Albedo) lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:01,126 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for Albedo! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:01,127 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: LAI)  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:01,128 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for LAI!   lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:01,129 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: FC)   lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:01,130 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for FC!    lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:01,188 hmc_logger   INFO     ------> WARNING:  All air pressure values are equal to 101.3 [kPa]! AirPressure will be initialized using altitude (DEM) information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:01,203 hmc_logger   INFO     ------> WARNING:  All LAI values are undefined! LAI will be initialized using monthly mean information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:01,209 hmc_logger   INFO     ------> WARNING:  Fractional vegetation Cover set equal to one!                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:01,215 hmc_logger   INFO     ------> WARNING:  All albedo values are undefined! Albedo will be initialized using monthly mean information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:01,221 hmc_logger   INFO     ------> WARNING:  No compressed updating netCDF data found: /home/fabio/fp_run_hmc/jupyter_ws/forcing/gridded/hmc.updating-grid.202101270400.nc.gz lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:01,257 hmc_logger   INFO     ------> WARNING:  All snow mask values are undefined! Check updating data! Snow physics is not activated! If Snow mask is provided by external file, check updating data! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:01,615 hmc_logger   INFO     ---->  Phys :: LSM :: IntegrationStep ::  900   [s]                              lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:01,618 hmc_logger   INFO     ---->  Phys :: LSM :: AvgValue ::  LST: 268.5      [K]  Rn:  -43.1     [W/m^2]  H:   -5.1     [W/m^2]  LE:    3.8     [W/m^2] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:01,649 hmc_logger   INFO     ---->  Phys :: EVT :: AvgValue ::  AE:  0.0060    [mm]  ET:  0.0054    [mm]  ET Tot:  0.0345    [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:01,725 hmc_logger   INFO     ---->  Phys :: Convolution :: IntegrationStep ::   24       [s]                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:01,727 hmc_logger   INFO     ---->  Phys :: Convolution :: MaxValue ::  Uc:  7.55968   [m/s]  Rain:  0.00000   [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:15,337 hmc_logger   INFO     ---->  Phys :: Convolution :: Discharge :: Q SecFirst:      25.94 [m^3/s] Q SecMax:     109.75 [m^3/s] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:18,576 hmc_logger   INFO     ---->  STEP CLOCK END :: Time: 2021-01-29 17:10:18.575                           lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:18,581 hmc_logger   INFO     ---->  ===== TIME STEP END :: Date, iT, iNTime, iDt :: 2021-01-27_04:00:00            5           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:18,582 hmc_logger   INFO     ---->  ===== TIME STEP START :: Date, iT, iNTime, iDt, Clock :: 2021-01-27_05:00:00            6           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:18,584 hmc_logger   INFO     ---->  STEP CLOCK START :: Time: 2021-01-29 17:10:18.576                         lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:18,585 hmc_logger   INFO     ------> WARNING:  No forcing point ASCII data found (dam volume): /home/fabio/fp_run_hmc/jupyter_ws/forcing/point/damv.db.202101270500.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:18,762 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: AirPressure) lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:18,764 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for AirPressure! Variable initializes in default mode using Altitude values! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:18,767 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: Albedo) lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:18,771 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for Albedo! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:18,775 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: LAI)  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:18,776 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for LAI!   lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:18,777 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: FC)   lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:18,777 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for FC!    lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:18,830 hmc_logger   INFO     ------> WARNING:  All air pressure values are equal to 101.3 [kPa]! AirPressure will be initialized using altitude (DEM) information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:18,844 hmc_logger   INFO     ------> WARNING:  All LAI values are undefined! LAI will be initialized using monthly mean information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:18,849 hmc_logger   INFO     ------> WARNING:  Fractional vegetation Cover set equal to one!                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:18,853 hmc_logger   INFO     ------> WARNING:  All albedo values are undefined! Albedo will be initialized using monthly mean information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:18,860 hmc_logger   INFO     ------> WARNING:  No compressed updating netCDF data found: /home/fabio/fp_run_hmc/jupyter_ws/forcing/gridded/hmc.updating-grid.202101270500.nc.gz lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:18,889 hmc_logger   INFO     ------> WARNING:  All snow mask values are undefined! Check updating data! Snow physics is not activated! If Snow mask is provided by external file, check updating data! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:19,258 hmc_logger   INFO     ---->  Phys :: LSM :: IntegrationStep ::  900   [s]                              lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:19,260 hmc_logger   INFO     ---->  Phys :: LSM :: AvgValue ::  LST: 268.2      [K]  Rn:  -41.0     [W/m^2]  H:   -5.6     [W/m^2]  LE:    3.4     [W/m^2] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:19,291 hmc_logger   INFO     ---->  Phys :: EVT :: AvgValue ::  AE:  0.0054    [mm]  ET:  0.0049    [mm]  ET Tot:  0.0399    [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:19,368 hmc_logger   INFO     ---->  Phys :: Convolution :: IntegrationStep ::   24       [s]                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:19,370 hmc_logger   INFO     ---->  Phys :: Convolution :: MaxValue ::  Uc:  7.57547   [m/s]  Rain:  0.00000   [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:32,667 hmc_logger   INFO     ---->  Phys :: Convolution :: Discharge :: Q SecFirst:      25.82 [m^3/s] Q SecMax:     110.68 [m^3/s] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:35,746 hmc_logger   INFO     ---->  STEP CLOCK END :: Time: 2021-01-29 17:10:35.746                           lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:35,748 hmc_logger   INFO     ---->  ===== TIME STEP END :: Date, iT, iNTime, iDt :: 2021-01-27_05:00:00            6           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:35,750 hmc_logger   INFO     ---->  ===== TIME STEP START :: Date, iT, iNTime, iDt, Clock :: 2021-01-27_06:00:00            7           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:35,751 hmc_logger   INFO     ---->  STEP CLOCK START :: Time: 2021-01-29 17:10:35.747                         lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:35,752 hmc_logger   INFO     ------> WARNING:  No forcing point ASCII data found (dam volume): /home/fabio/fp_run_hmc/jupyter_ws/forcing/point/damv.db.202101270600.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:35,927 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: AirPressure) lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:35,928 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for AirPressure! Variable initializes in default mode using Altitude values! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:35,929 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: Albedo) lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:35,931 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for Albedo! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:35,938 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: LAI)  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:35,941 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for LAI!   lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:35,942 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: FC)   lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:35,944 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for FC!    lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:36,017 hmc_logger   INFO     ------> WARNING:  All air pressure values are equal to 101.3 [kPa]! AirPressure will be initialized using altitude (DEM) information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:36,031 hmc_logger   INFO     ------> WARNING:  All LAI values are undefined! LAI will be initialized using monthly mean information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:36,037 hmc_logger   INFO     ------> WARNING:  Fractional vegetation Cover set equal to one!                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:36,041 hmc_logger   INFO     ------> WARNING:  All albedo values are undefined! Albedo will be initialized using monthly mean information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:36,047 hmc_logger   INFO     ------> WARNING:  No compressed updating netCDF data found: /home/fabio/fp_run_hmc/jupyter_ws/forcing/gridded/hmc.updating-grid.202101270600.nc.gz lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:36,082 hmc_logger   INFO     ------> WARNING:  All snow mask values are undefined! Check updating data! Snow physics is not activated! If Snow mask is provided by external file, check updating data! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:36,479 hmc_logger   INFO     ---->  Phys :: LSM :: IntegrationStep ::  900   [s]                              lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:36,480 hmc_logger   INFO     ---->  Phys :: LSM :: AvgValue ::  LST: 267.8      [K]  Rn:  -40.8     [W/m^2]  H:   -4.5     [W/m^2]  LE:    2.4     [W/m^2] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:36,514 hmc_logger   INFO     ---->  Phys :: EVT :: AvgValue ::  AE:  0.0038    [mm]  ET:  0.0035    [mm]  ET Tot:  0.0437    [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:36,593 hmc_logger   INFO     ---->  Phys :: Convolution :: IntegrationStep ::   24       [s]                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:36,595 hmc_logger   INFO     ---->  Phys :: Convolution :: MaxValue ::  Uc:  7.59466   [m/s]  Rain:  0.00000   [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:50,018 hmc_logger   INFO     ---->  Phys :: Convolution :: Discharge :: Q SecFirst:      25.91 [m^3/s] Q SecMax:     110.63 [m^3/s] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:53,077 hmc_logger   INFO     ---->  STEP CLOCK END :: Time: 2021-01-29 17:10:53.076                           lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:53,078 hmc_logger   INFO     ---->  ===== TIME STEP END :: Date, iT, iNTime, iDt :: 2021-01-27_06:00:00            7           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:53,083 hmc_logger   INFO     ---->  ===== TIME STEP START :: Date, iT, iNTime, iDt, Clock :: 2021-01-27_07:00:00            8           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:53,084 hmc_logger   INFO     ---->  STEP CLOCK START :: Time: 2021-01-29 17:10:53.077                         lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:53,088 hmc_logger   INFO     ------> WARNING:  No forcing point ASCII data found (dam volume): /home/fabio/fp_run_hmc/jupyter_ws/forcing/point/damv.db.202101270700.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:53,233 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: AirPressure) lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:53,235 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for AirPressure! Variable initializes in default mode using Altitude values! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:53,239 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: Albedo) lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:53,241 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for Albedo! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:53,243 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: LAI)  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:53,247 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for LAI!   lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:53,248 hmc_logger   INFO     ------> WARNING:  INQUIRE FAILED :: Get2d_NC ---> nf90_inq_varid (varname: FC)   lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:53,251 hmc_logger   INFO     ------> WARNING:  Get forcing gridded data FAILED! Check forcing data for FC!    lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:53,316 hmc_logger   INFO     ------> WARNING:  All air pressure values are equal to 101.3 [kPa]! AirPressure will be initialized using altitude (DEM) information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:53,329 hmc_logger   INFO     ------> WARNING:  All LAI values are undefined! LAI will be initialized using monthly mean information! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:10:53,333 hmc_logger   INFO     ------> WARNING:  Fractional vegetation Cover set equal to one!                  lib_utils_process.py:[64     - exec_process        ()]
# ...
# 2021-01-29 17:21:50,589 hmc_logger   INFO     ---->  Phys :: Convolution :: IntegrationStep ::   24       [s]                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:21:50,591 hmc_logger   INFO     ---->  Phys :: Convolution :: MaxValue ::  Uc:  7.42017   [m/s]  Rain:  0.00000   [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:05,757 hmc_logger   INFO     ---->  Phys :: Convolution :: Discharge :: Q SecFirst:      23.88 [m^3/s] Q SecMax:      88.48 [m^3/s] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:09,516 hmc_logger   INFO     ---->  STEP CLOCK END :: Time: 2021-01-29 17:22:09.515                           lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:09,517 hmc_logger   INFO     ---->  ===== TIME STEP END :: Date, iT, iNTime, iDt :: 2021-01-28_16:00:00           41           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:09,518 hmc_logger   INFO     ---->  ===== TIME STEP START :: Date, iT, iNTime, iDt, Clock :: 2021-01-28_17:00:00           42           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:09,519 hmc_logger   INFO     ---->  STEP CLOCK START :: Time: 2021-01-29 17:22:09.516                         lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:09,523 hmc_logger   INFO     ------> WARNING:  No forcing point ASCII data found (dam volume): /home/fabio/fp_run_hmc/jupyter_ws/forcing/point/damv.db.202101281700.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:09,556 hmc_logger   INFO     ------> WARNING:  All snow mask values are undefined! Check updating data! Snow physics is not activated! If Snow mask is provided by external file, check updating data! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:09,976 hmc_logger   INFO     ---->  Phys :: LSM :: IntegrationStep ::  900   [s]                              lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:09,982 hmc_logger   INFO     ---->  Phys :: LSM :: AvgValue ::  LST: 273.8      [K]  Rn:  -78.3     [W/m^2]  H:    0.1     [W/m^2]  LE:    1.3     [W/m^2] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:10,014 hmc_logger   INFO     ---->  Phys :: EVT :: AvgValue ::  AE:  0.0018    [mm]  ET:  0.0018    [mm]  ET Tot:  0.7669    [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:10,084 hmc_logger   INFO     ---->  Phys :: Convolution :: IntegrationStep ::   24       [s]                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:10,087 hmc_logger   INFO     ---->  Phys :: Convolution :: MaxValue ::  Uc:  7.41386   [m/s]  Rain:  0.00000   [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:25,639 hmc_logger   INFO     ---->  Phys :: Convolution :: Discharge :: Q SecFirst:      23.80 [m^3/s] Q SecMax:      87.84 [m^3/s] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:29,564 hmc_logger   INFO     ---->  STEP CLOCK END :: Time: 2021-01-29 17:22:29.564                           lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:29,565 hmc_logger   INFO     ---->  ===== TIME STEP END :: Date, iT, iNTime, iDt :: 2021-01-28_17:00:00           42           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:29,571 hmc_logger   INFO     ---->  ===== TIME STEP START :: Date, iT, iNTime, iDt, Clock :: 2021-01-28_18:00:00           43           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:29,573 hmc_logger   INFO     ---->  STEP CLOCK START :: Time: 2021-01-29 17:22:29.564                         lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:29,575 hmc_logger   INFO     ------> WARNING:  No forcing point ASCII data found (dam volume): /home/fabio/fp_run_hmc/jupyter_ws/forcing/point/damv.db.202101281800.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:29,601 hmc_logger   INFO     ------> WARNING:  All snow mask values are undefined! Check updating data! Snow physics is not activated! If Snow mask is provided by external file, check updating data! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:29,638 hmc_logger   INFO     ---->  Phys :: EVT :: AvgValue ::  AE:  0.2085    [mm]  ET:  0.2085    [mm]  ET Tot:  0.9754    [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:29,710 hmc_logger   INFO     ---->  Phys :: Convolution :: IntegrationStep ::   24       [s]                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:29,711 hmc_logger   INFO     ---->  Phys :: Convolution :: MaxValue ::  Uc:  7.40725   [m/s]  Rain:  0.00000   [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:45,365 hmc_logger   INFO     ---->  Phys :: Convolution :: Discharge :: Q SecFirst:      23.72 [m^3/s] Q SecMax:      87.20 [m^3/s] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:49,412 hmc_logger   INFO     ---->  STEP CLOCK END :: Time: 2021-01-29 17:22:49.412                           lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:49,414 hmc_logger   INFO     ---->  ===== TIME STEP END :: Date, iT, iNTime, iDt :: 2021-01-28_18:00:00           43           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:49,424 hmc_logger   INFO     ---->  ===== TIME STEP START :: Date, iT, iNTime, iDt, Clock :: 2021-01-28_19:00:00           44           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:49,426 hmc_logger   INFO     ---->  STEP CLOCK START :: Time: 2021-01-29 17:22:49.412                         lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:49,428 hmc_logger   INFO     ------> WARNING:  No forcing point ASCII data found (dam volume): /home/fabio/fp_run_hmc/jupyter_ws/forcing/point/damv.db.202101281900.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:49,452 hmc_logger   INFO     ------> WARNING:  All snow mask values are undefined! Check updating data! Snow physics is not activated! If Snow mask is provided by external file, check updating data! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:49,490 hmc_logger   INFO     ---->  Phys :: EVT :: AvgValue ::  AE:  0.2084    [mm]  ET:  0.2085    [mm]  ET Tot:  1.1839    [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:49,562 hmc_logger   INFO     ---->  Phys :: Convolution :: IntegrationStep ::   24       [s]                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:22:49,564 hmc_logger   INFO     ---->  Phys :: Convolution :: MaxValue ::  Uc:  7.39910   [m/s]  Rain:  0.00000   [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:05,714 hmc_logger   INFO     ---->  Phys :: Convolution :: Discharge :: Q SecFirst:      23.65 [m^3/s] Q SecMax:      86.56 [m^3/s] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:09,847 hmc_logger   INFO     ---->  STEP CLOCK END :: Time: 2021-01-29 17:23:09.847                           lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:09,849 hmc_logger   INFO     ---->  ===== TIME STEP END :: Date, iT, iNTime, iDt :: 2021-01-28_19:00:00           44           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:09,856 hmc_logger   INFO     ---->  ===== TIME STEP START :: Date, iT, iNTime, iDt, Clock :: 2021-01-28_20:00:00           45           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:09,859 hmc_logger   INFO     ---->  STEP CLOCK START :: Time: 2021-01-29 17:23:09.847                         lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:09,861 hmc_logger   INFO     ------> WARNING:  No forcing point ASCII data found (dam volume): /home/fabio/fp_run_hmc/jupyter_ws/forcing/point/damv.db.202101282000.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:09,889 hmc_logger   INFO     ------> WARNING:  All snow mask values are undefined! Check updating data! Snow physics is not activated! If Snow mask is provided by external file, check updating data! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:09,926 hmc_logger   INFO     ---->  Phys :: EVT :: AvgValue ::  AE:  0.2082    [mm]  ET:  0.2085    [mm]  ET Tot:  1.3921    [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:10,003 hmc_logger   INFO     ---->  Phys :: Convolution :: IntegrationStep ::   24       [s]                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:10,005 hmc_logger   INFO     ---->  Phys :: Convolution :: MaxValue ::  Uc:  7.38798   [m/s]  Rain:  0.00000   [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:26,759 hmc_logger   INFO     ---->  Phys :: Convolution :: Discharge :: Q SecFirst:      23.57 [m^3/s] Q SecMax:      85.93 [m^3/s] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:31,456 hmc_logger   INFO     ---->  STEP CLOCK END :: Time: 2021-01-29 17:23:31.456                           lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:31,457 hmc_logger   INFO     ---->  ===== TIME STEP END :: Date, iT, iNTime, iDt :: 2021-01-28_20:00:00           45           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:31,458 hmc_logger   INFO     ---->  ===== TIME STEP START :: Date, iT, iNTime, iDt, Clock :: 2021-01-28_21:00:00           46           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:31,460 hmc_logger   INFO     ---->  STEP CLOCK START :: Time: 2021-01-29 17:23:31.456                         lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:31,466 hmc_logger   INFO     ------> WARNING:  No forcing point ASCII data found (dam volume): /home/fabio/fp_run_hmc/jupyter_ws/forcing/point/damv.db.202101282100.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:31,508 hmc_logger   INFO     ------> WARNING:  All snow mask values are undefined! Check updating data! Snow physics is not activated! If Snow mask is provided by external file, check updating data! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:31,573 hmc_logger   INFO     ---->  Phys :: EVT :: AvgValue ::  AE:  0.2078    [mm]  ET:  0.2085    [mm]  ET Tot:  1.5999    [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:31,672 hmc_logger   INFO     ---->  Phys :: Convolution :: IntegrationStep ::   24       [s]                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:31,674 hmc_logger   INFO     ---->  Phys :: Convolution :: MaxValue ::  Uc:  7.37810   [m/s]  Rain:  0.00000   [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:48,975 hmc_logger   INFO     ---->  Phys :: Convolution :: Discharge :: Q SecFirst:      23.49 [m^3/s] Q SecMax:      85.31 [m^3/s] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:53,683 hmc_logger   INFO     ---->  STEP CLOCK END :: Time: 2021-01-29 17:23:53.683                           lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:53,685 hmc_logger   INFO     ---->  ===== TIME STEP END :: Date, iT, iNTime, iDt :: 2021-01-28_21:00:00           46           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:53,686 hmc_logger   INFO     ---->  ===== TIME STEP START :: Date, iT, iNTime, iDt, Clock :: 2021-01-28_22:00:00           47           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:53,687 hmc_logger   INFO     ---->  STEP CLOCK START :: Time: 2021-01-29 17:23:53.684                         lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:53,689 hmc_logger   INFO     ------> WARNING:  No forcing point ASCII data found (dam volume): /home/fabio/fp_run_hmc/jupyter_ws/forcing/point/damv.db.202101282200.txt lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:53,740 hmc_logger   INFO     ------> WARNING:  All snow mask values are undefined! Check updating data! Snow physics is not activated! If Snow mask is provided by external file, check updating data! lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:53,807 hmc_logger   INFO     ---->  Phys :: EVT :: AvgValue ::  AE:  0.2074    [mm]  ET:  0.2085    [mm]  ET Tot:  1.8072    [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:53,896 hmc_logger   INFO     ---->  Phys :: Convolution :: IntegrationStep ::   24       [s]                  lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:23:53,899 hmc_logger   INFO     ---->  Phys :: Convolution :: MaxValue ::  Uc:  7.36947   [m/s]  Rain:  0.00000   [mm] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:24:11,653 hmc_logger   INFO     ---->  Phys :: Convolution :: Discharge :: Q SecFirst:      23.41 [m^3/s] Q SecMax:      84.66 [m^3/s] lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:24:16,242 hmc_logger   INFO     ---->  STEP CLOCK END :: Time: 2021-01-29 17:24:16.242                           lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:24:16,243 hmc_logger   INFO     ---->  ===== TIME STEP END :: Date, iT, iNTime, iDt :: 2021-01-28_22:00:00           47           42         3600 ===== lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:24:16,245 hmc_logger   INFO     ---->  SIMULATION END :: Time: 2021-01-29 17:24:16.242                           lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:24:16,248 hmc_logger   INFO     ----> ************************************************************************   lib_utils_process.py:[64     - exec_process        ()]
# 2021-01-29 17:24:16,333 hmc_logger   WARNING   ===> Process POOL = 0 KILLED!                                                   lib_utils_process.py:[58     - exec_process        ()]
# 2021-01-29 17:24:16,334 hmc_logger   INFO      ------> Process execution: /home/fabio/fp_run_hmc/jupyter_ws/exec/HMC_Model_V3_jupyter_ws.x /home/fabio/fp_run_hmc/jupyter_ws/exec/marche.info.txt ... DONE lib_utils_process.py:[79     - exec_process        ()]
# 2021-01-29 17:24:16,336 hmc_logger   INFO      ----> Analyze run deterministic ...                                             cpl_hmc_runner.py:[144    - configure_execution ()]
# 2021-01-29 17:24:16,337 hmc_logger   INFO      -----> StdOut: None                                                             cpl_hmc_runner.py:[145    - configure_execution ()]
# 2021-01-29 17:24:16,339 hmc_logger   INFO      -----> StdErr: None                                                             cpl_hmc_runner.py:[146    - configure_execution ()]
# 2021-01-29 17:24:16,340 hmc_logger   INFO      -----> StdExit: 0                                                               cpl_hmc_runner.py:[166    - configure_execution ()]
# 2021-01-29 17:24:16,341 hmc_logger   INFO      ----> Analyze run deterministic ... DONE                                        cpl_hmc_runner.py:[175    - configure_execution ()]
# 2021-01-29 17:24:16,344 hmc_logger   INFO      #### Configure execution ... DONE                                               cpl_hmc_runner.py:[184    - configure_execution ()]
#  ==> Execute the model run ... DONE

# %% [markdown]
# ### **Finalize the instance of the Continuum model**
# - Configure the finalizer class of the model

# %%
# Info
print(' ==> Configure the model finalizer class ... ')

# Set the verbose debug level
log_stream.setLevel(logging.ERROR)

# Configure model finalizer class
driver_hmc_finalizer = ModelFinalizer(
    collection_dynamic=forcing_datasets_collections,
    obj_geo_reference=driver_hmc_initializer.dset_ref_geo,
    obj_args=driver_hmc_initializer.obj_args,
    obj_run=driver_hmc_initializer.obj_run,
    obj_ancillary=driver_hmc_initializer.obj_ancillary)

# Info
print(' ==> Configure the model finalizer class ... DONE')
# Out:
#  ==> Configure the model finalizer class ...
#  ==> Configure the model finalizer class ... DONE

# %% [markdown]
# - Dump the model results in gridded, point and time-series format

# %%
# Info
print(' ==> Dump the model outcome datasets ... ')

# Set the verbose debug level
log_stream.setLevel(logging.ERROR)

# Configure the outcome datasets
outcome_datasets_collections = driver_hmc_finalizer.configure_dynamic_datasets(
    time_series_collections, time_info_collections, static_datasets_collections, ancillary_datasets_collections)

# Info
print(' ==> Dump the model outcome datasets ... DONE')
# Out:
#  ==> Dump the model outcome datasets ...
#  ==> Dump the model outcome datasets ... DONE

# %% [markdown]
# - Dump the model results in collections format

# %%
# Info
print(' ==> Dump the model summary datasets ... ')

# Set the verbose debug level
log_stream.setLevel(logging.ERROR)

# Configure the summary datasets
driver_hmc_finalizer.configure_summary_datasets(
    time_series_collections, time_info_collections, static_datasets_collections, outcome_datasets_collections)

# Info
print(' ==> Dump the model summary datasets ... DONE')
# Out:
#  ==> Dump the model summary datasets ...
#  ==> Dump the model summary datasets ... DONE

# %% [markdown]
# **Training on-the-job**
# - Download/Organize the static and dynamic datasets for a different "time run";
# - Select a different case-study (time run);
# - Run the Continuum model for a different case-study;
# - Run the Continuum model for a different run-type (for example observed weather stations and nwp forecast maps);
# - ...
